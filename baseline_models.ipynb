# %% [markdown]
# # Game RecSys: Baseline Models
# In this notebook I develop baseline models for the recommender system

# %%
import numpy as np
import pandas as pd
from surprise import Reader, Dataset, SVD

# %% [markdown]
# ## Load and format the data
# ### Training data

# %%
X_train = pd.read_csv("train_test_split/X_train_3k.csv")
X_train = X_train.set_index("Unnamed: 0")
y_train = pd.read_csv("train_test_split/y_train_3k.csv")
y_train = y_train.set_index("Unnamed: 0")
# join and reset index
train_df = pd.merge(X_train, y_train, left_index=True, right_index=True, validate="1:1")
train_df = train_df.reset_index(drop=True)

# %% [markdown]
# ### Test data

# %%
X_test = pd.read_csv("train_test_split/X_test_3k.csv")
X_test = X_test.set_index("Unnamed: 0")
y_test = pd.read_csv("train_test_split/y_test_3k.csv")
y_test = y_test.set_index("Unnamed: 0")
# join and reset index
test_df = pd.merge(X_test, y_test, left_index=True, right_index=True, validate="1:1")
test_df = test_df.reset_index(drop=True)

# %%
test_df
# Out:
#                                    funny  \
# 0                                    NaN
# 1                                    NaN
# 2                                    NaN
# 3                                    NaN
# 4                                    NaN
# 5                                    NaN
# 6                                    NaN
# 7       1 person found this review funny
# 8                                    NaN
# 9                                    NaN
# 10                                   NaN
# 11      2 people found this review funny
# 12      1 person found this review funny
# 13                                   NaN
# 14      1 person found this review funny
# 15      3 people found this review funny
# 16                                   NaN
# 17                                   NaN
# 18      3 people found this review funny
# 19                                   NaN
# 20                                   NaN
# 21                                   NaN
# 22                                   NaN
# 23                                   NaN
# 24                                   NaN
# 25                                   NaN
# 26                                   NaN
# 27                                   NaN
# 28                                   NaN
# 29                                   NaN
# ...                                  ...
# 8293                                 NaN
# 8294                                 NaN
# 8295                                 NaN
# 8296    1 person found this review funny
# 8297                                 NaN
# 8298                                 NaN
# 8299    3 people found this review funny
# 8300                                 NaN
# 8301                                 NaN
# 8302  144 people found this review funny
# 8303    2 people found this review funny
# 8304                                 NaN
# 8305                                 NaN
# 8306                                 NaN
# 8307                                 NaN
# 8308                                 NaN
# 8309                                 NaN
# 8310   14 people found this review funny
# 8311                                 NaN
# 8312    2 people found this review funny
# 8313                                 NaN
# 8314                                 NaN
# 8315                                 NaN
# 8316                                 NaN
# 8317                                 NaN
# 8318                                 NaN
# 8319                                 NaN
# 8320    1 person found this review funny
# 8321                                 NaN
# 8322                                 NaN
#
#                                                 helpful  item_id  \
# 0                                        No ratings yet   386360
# 1        2 of 2 people (100%) found this review helpful     4000
# 2                                        No ratings yet     1250
# 3                                        No ratings yet   200210
# 4                                        No ratings yet     4000
# 5          0 of 1 people (0%) found this review helpful   377160
# 6        1 of 1 people (100%) found this review helpful   261980
# 7         3 of 5 people (60%) found this review helpful      730
# 8                                        No ratings yet    34330
# 9                                        No ratings yet   271290
# 10                                       No ratings yet   113200
# 11       1 of 1 people (100%) found this review helpful   220260
# 12       2 of 2 people (100%) found this review helpful      730
# 13                                       No ratings yet   252490
# 14       9 of 13 people (69%) found this review helpful   403190
# 15      21 of 33 people (64%) found this review helpful   206210
# 16       1 of 10 people (10%) found this review helpful    12900
# 17                                       No ratings yet      730
# 18        3 of 5 people (60%) found this review helpful   335240
# 19       1 of 1 people (100%) found this review helpful    70000
# 20                                       No ratings yet   302510
# 21        5 of 6 people (83%) found this review helpful    24240
# 22        1 of 2 people (50%) found this review helpful   207610
# 23       5 of 12 people (42%) found this review helpful   237110
# 24                                       No ratings yet   214700
# 25                                       No ratings yet     4000
# 26      16 of 23 people (70%) found this review helpful   212070
# 27                                       No ratings yet    35140
# 28        1 of 2 people (50%) found this review helpful     4000
# 29         0 of 3 people (0%) found this review helpful   218620
# ...                                                 ...      ...
# 8293       0 of 1 people (0%) found this review helpful   224600
# 8294     1 of 1 people (100%) found this review helpful      550
# 8295                                     No ratings yet   227300
# 8296                                     No ratings yet   211420
# 8297     1 of 1 people (100%) found this review helpful   221910
# 8298      4 of 8 people (50%) found this review helpful      550
# 8299      3 of 4 people (75%) found this review helpful   387860
# 8300                                     No ratings yet   210770
# 8301                                     No ratings yet    24960
# 8302  127 of 161 people (79%) found this review helpful   359050
# 8303     2 of 2 people (100%) found this review helpful   333600
# 8304                                     No ratings yet   113200
# 8305      1 of 3 people (33%) found this review helpful   233250
# 8306      3 of 4 people (75%) found this review helpful      440
# 8307     7 of 14 people (50%) found this review helpful     3483
# 8308       0 of 2 people (0%) found this review helpful   209870
# 8309                                     No ratings yet   236450
# 8310   94 of 108 people (87%) found this review helpful   433340
# 8311                                     No ratings yet   233630
# 8312      2 of 3 people (67%) found this review helpful      440
# 8313                                     No ratings yet     4000
# 8314      1 of 2 people (50%) found this review helpful   210770
# 8315                                     No ratings yet      730
# 8316       0 of 1 people (0%) found this review helpful   113400
# 8317                                     No ratings yet      440
# 8318                                     No ratings yet     8980
# 8319                                     No ratings yet    35140
# 8320     2 of 2 people (100%) found this review helpful      730
# 8321                                     No ratings yet   230410
# 8322                                     No ratings yet   212800
#
#                           last_edited                      posted  \
# 0                                 NaN         Posted February 26.
# 1     Last edited September 30, 2015.       Posted June 20, 2013.
# 2                                 NaN        Posted May 25, 2015.
# 3                                 NaN    Posted January 10, 2014.
# 4                                 NaN    Posted February 1, 2014.
# 5                Last edited July 20.             Posted July 20.
# 6                                 NaN    Posted December 4, 2013.
# 7                                 NaN   Posted December 21, 2013.
# 8                                 NaN       Posted July 23, 2014.
# 9                                 NaN   Posted February 15, 2014.
# 10                                NaN    Posted October 11, 2014.
# 11                                NaN  Posted September 20, 2014.
# 12                                NaN   Posted December 12, 2014.
# 13                                NaN           Posted January 5.
# 14      Last edited October 28, 2015.    Posted October 27, 2015.
# 15                                NaN    Posted October 16, 2014.
# 16                                NaN   Posted November 29, 2013.
# 17                                NaN   Posted December 20, 2013.
# 18                                NaN       Posted July 18, 2015.
# 19                                NaN   Posted December 25, 2013.
# 20                                NaN    Posted February 1, 2015.
# 21                                NaN    Posted October 16, 2014.
# 22         Last edited June 21, 2014.   Posted December 28, 2013.
# 23                                NaN    Posted October 28, 2015.
# 24                                NaN        Posted May 13, 2015.
# 25                                NaN   Posted February 14, 2012.
# 26                                NaN     Posted October 2, 2014.
# 27                                NaN      Posted April 27, 2015.
# 28                                NaN   Posted December 10, 2012.
# 29                                NaN          Posted February 6.
# ...                               ...                         ...
# 8293                              NaN       Posted March 7, 2015.
# 8294                              NaN       Posted June 30, 2014.
# 8295                              NaN         Posted February 25.
# 8296                              NaN     Posted August 17, 2013.
# 8297                              NaN       Posted March 8, 2014.
# 8298                              NaN       Posted June 16, 2013.
# 8299                              NaN    Posted December 2, 2015.
# 8300                              NaN   Posted November 23, 2014.
# 8301                              NaN  Posted September 12, 2015.
# 8302                              NaN   Posted September 6, 2015.
# 8303                              NaN      Posted April 13, 2015.
# 8304                              NaN     Posted January 9, 2015.
# 8305                              NaN    Posted January 10, 2015.
# 8306                              NaN   Posted February 14, 2014.
# 8307   Last edited November 25, 2013.   Posted November 14, 2013.
# 8308                              NaN       Posted July 19, 2012.
# 8309                              NaN       Posted June 13, 2015.
# 8310                              NaN          Posted January 30.
# 8311                              NaN        Posted May 22, 2014.
# 8312                              NaN            Posted March 16.
# 8313                              NaN     Posted January 1, 2015.
# 8314                              NaN   Posted November 28, 2013.
# 8315                              NaN          Posted January 15.
# 8316                              NaN       Posted March 5, 2015.
# 8317                              NaN   Posted November 13, 2014.
# 8318            Last edited March 29.         Posted February 15.
# 8319                              NaN        Posted June 3, 2014.
# 8320    Last edited December 2, 2014.      Posted April 25, 2014.
# 8321                              NaN       Posted March 6, 2015.
# 8322                              NaN        Posted May 11, 2013.
#
#                                                  review  \
# 0     Pfft, everyone is waiting for jesus, i am wati...
# 1     great if you like building role playing , bein...
# 2          Best zombie game on PC by far in my opinion!
# 3     guooo me envicio muchooooooooooooooooo ahahaha...
# 4                                  i give it a crash/10
# 5              what to do with this game: download mods
# 6                           Confusion & program crashes
# 7                                               Buy....
# 8     The height of Total War glory and creation. Gr...
# 9     If you played MechWarrior or still do you are ...
# 10    its like the first zelda on the NES mixed with...
# 11    I have spent months and months on this game :)...
# 12    *Gets kicked for not surrendering gets 7 day b...
# 13    10/10 ran around for 60mins trying to find at ...
# 14    This game gives user an achievement when they ...
# 15    I like the game it is whacky and fun, But when...
# 16         Dis is an pretty poopy game$2 not well spent
# 17                           Easily The best FPS On PC!
# 18    GREAT Free to play game.Started playing at 5pm...
# 19                     Espero que regalen este Juego :D
# 20    Excelent gameplay, short but good storyline, m...
# 21    à¸«à¸™à¸¸à¸à¸¡à¸²à¸à¸„à¸£à¸±à¸š à¸‹à¸·à¹‰à¸­à¹...
# 22    No game has made me Cry until this Game. Any g...
# 23           When Krap goes digital it looks like this.
# 24    This is amazing.But you should probably get th...
# 25    Really funny stuff! Great game for people with...
# 26    I liked the intro. But it took so long to get ...
# 27    I was pleasently suprised how much i enjoyed t...
# 28                           this is the best game EVER
# 29                                                10/10
# ...                                                 ...
# 8293  Slightly annoyed that i bought multiple copies...
# 8294            muito legal Ã© melhor ainda cooperativo
# 8295  Muy Bueno El Juego te entretiene y se vuelve v...
# 8296                                            Indeed.
# 8297            a brilliant game with a brilliant story
# 8298  Suck â™¥â™¥â™¥ game with power abusers in it, ...
# 8299  Can't stop playing this game!There is so much ...
# 8300  Being able to jump into a perfectly stategised...
# 8301  Seemed interesting but couldnt continue furthe...
# 8302        Why does the black dad always disappear? :(
# 8303  The game is OK i guess, but i think ill need t...
# 8304                                       ES BUENISIMO
# 8305   all of the units and buildings are invisible! :(
# 8306  Best First Person Shooter... Ever.  For all ti...
# 8307  It didnt even take an hour to complete the Sto...
# 8308  Recomendo todos baixar por q e de draÃ§a :/......
# 8309  It's pack man on acid.A lot of fun, get it whi...
# 8310  Pros- Really fun- Easy to play- Looks amazing-...
# 8311  Like pikmin and shadow of the collosus togethe...
# 8312  This game is ok I dont think this game will di...
# 8313  BOM PRA KCT!! nessa budega vc faz qualquer coi...
# 8314  Great game, very addictive and now worth 3 dol...
# 8315                                   Its â™¥â™¥â™¥â™¥
# 8316  à¹€à¸à¸¡à¸™à¸µà¹‰à¹€à¸¥à¹ˆà¸™à¹à¸¥à¹‰à¸§à¸ªà¸™...
# 8317  this was my first game on steam, recommended t...
# 8318  Not as good as BL2, but still worth a play if ...
# 8319  Batman's trip to the asylum has hardly any fla...
# 8320  I have recently just started playing competiti...
# 8321                                   I am a NINJA lol
# 8322            looks good im gonna get it.....maybe ;)
#
#                          user_id  \
# 0                    sickbubblez
# 1     GetALifeStopLookingAtMyUrl
# 2                    kineticvine
# 3                      LeoNoHomo
# 4                   itsdandytime
# 5              76561198134824579
# 6                     Gemini_Tiw
# 7              76561198066969630
# 8              76561198064162552
# 9                         u2late
# 10          stopreadingthisthing
# 11                  nofeardave83
# 12                     Lembladez
# 13             76561198050945208
# 14                    terrill000
# 15             76561198105430566
# 16                      tomtuker
# 17                    kapoweazel
# 18                     channel28
# 19              MarsupialesLocos
# 20                   Donato_Dyas
# 21                TheTrollScript
# 22             76561198088947777
# 23                    Black_Dawn
# 24                 NotForPikachu
# 25                       hugh244
# 26                      SlurpDog
# 27             76561198052705581
# 28                      splitdip
# 29             76561198071457723
# ...                          ...
# 8293                      rgnr81
# 8294                      klDINO
# 8295               teimportaesto
# 8296                       NKraz
# 8297          moustachecashstash
# 8298             hunterkiller247
# 8299             jj_teh_jetplane
# 8300                       94567
# 8301                unkowncode94
# 8302                   rickoning
# 8303              DavieTheCheese
# 8304                  pipekissXD
# 8305                   derpmelon
# 8306                     PugsAus
# 8307                       Rawex
# 8308                HailAmeixing
# 8309                 SamuelTepes
# 8310              eeeeeeeeeltruT
# 8311                      171516
# 8312           76561198195478589
# 8313                   FD_GOD_BR
# 8314                OfficialMuir
# 8315           76561198083347489
# 8316                  kanzabrand
# 8317                   goonmurry
# 8318                  deejmyster
# 8319                  kharmakazi
# 8320               spankwankable
# 8321           vampirespyJL93TF2
# 8322                 ZennyAckbar
#
#                                                user_url  recommend
# 0              http://steamcommunity.com/id/sickbubblez          1
# 1     http://steamcommunity.com/id/GetALifeStopLooki...          1
# 2              http://steamcommunity.com/id/kineticvine          1
# 3                http://steamcommunity.com/id/LeoNoHomo          1
# 4             http://steamcommunity.com/id/itsdandytime          1
# 5     http://steamcommunity.com/profiles/76561198134...          1
# 6               http://steamcommunity.com/id/Gemini_Tiw          0
# 7     http://steamcommunity.com/profiles/76561198066...          1
# 8     http://steamcommunity.com/profiles/76561198064...          1
# 9                   http://steamcommunity.com/id/u2late          1
# 10    http://steamcommunity.com/id/stopreadingthisthing          1
# 11            http://steamcommunity.com/id/nofeardave83          1
# 12               http://steamcommunity.com/id/Lembladez          1
# 13    http://steamcommunity.com/profiles/76561198050...          1
# 14              http://steamcommunity.com/id/terrill000          0
# 15    http://steamcommunity.com/profiles/76561198105...          1
# 16                http://steamcommunity.com/id/tomtuker          0
# 17              http://steamcommunity.com/id/kapoweazel          1
# 18               http://steamcommunity.com/id/channel28          1
# 19        http://steamcommunity.com/id/MarsupialesLocos          1
# 20             http://steamcommunity.com/id/Donato_Dyas          1
# 21          http://steamcommunity.com/id/TheTrollScript          1
# 22    http://steamcommunity.com/profiles/76561198088...          1
# 23              http://steamcommunity.com/id/Black_Dawn          0
# 24           http://steamcommunity.com/id/NotForPikachu          1
# 25                 http://steamcommunity.com/id/hugh244          1
# 26                http://steamcommunity.com/id/SlurpDog          0
# 27    http://steamcommunity.com/profiles/76561198052...          1
# 28                http://steamcommunity.com/id/splitdip          1
# 29    http://steamcommunity.com/profiles/76561198071...          1
# ...                                                 ...        ...
# 8293                http://steamcommunity.com/id/rgnr81          1
# 8294                http://steamcommunity.com/id/klDINO          1
# 8295         http://steamcommunity.com/id/teimportaesto          1
# 8296                 http://steamcommunity.com/id/NKraz          1
# 8297    http://steamcommunity.com/id/moustachecashstash          1
# 8298       http://steamcommunity.com/id/hunterkiller247          1
# 8299       http://steamcommunity.com/id/jj_teh_jetplane          1
# 8300                 http://steamcommunity.com/id/94567          1
# 8301          http://steamcommunity.com/id/unkowncode94          0
# 8302             http://steamcommunity.com/id/rickoning          1
# 8303        http://steamcommunity.com/id/DavieTheCheese          1
# 8304            http://steamcommunity.com/id/pipekissXD          1
# 8305             http://steamcommunity.com/id/derpmelon          0
# 8306               http://steamcommunity.com/id/PugsAus          1
# 8307                 http://steamcommunity.com/id/Rawex          1
# 8308          http://steamcommunity.com/id/HailAmeixing          1
# 8309           http://steamcommunity.com/id/SamuelTepes          1
# 8310        http://steamcommunity.com/id/eeeeeeeeeltruT          1
# 8311                http://steamcommunity.com/id/171516          1
# 8312  http://steamcommunity.com/profiles/76561198195...          1
# 8313             http://steamcommunity.com/id/FD_GOD_BR          1
# 8314          http://steamcommunity.com/id/OfficialMuir          1
# 8315  http://steamcommunity.com/profiles/76561198083...          1
# 8316            http://steamcommunity.com/id/kanzabrand          1
# 8317             http://steamcommunity.com/id/goonmurry          1
# 8318            http://steamcommunity.com/id/deejmyster          1
# 8319            http://steamcommunity.com/id/kharmakazi          1
# 8320         http://steamcommunity.com/id/spankwankable          1
# 8321     http://steamcommunity.com/id/vampirespyJL93TF2          1
# 8322           http://steamcommunity.com/id/ZennyAckbar          1
#
# [8323 rows x 9 columns]

# %% [markdown]
# ## Test a baseline recommender
# Uses static user-game baseline ratings to predict new game ratings

# %%
from surprise import BaselineOnly, accuracy
from surprise.model_selection import PredefinedKFold

# %%
# need to write files first in order for surprise to read them properly
train_df[["user_id", "item_id", "recommend"]].to_csv("train_test_split/surprise_train.csv",index=False)
test_df[["user_id", "item_id", "recommend"]].to_csv("train_test_split/surprise_test.csv", index=False)

# %%
# create a reader object
reader = Reader(rating_scale=(0, 1), sep=",", skip_lines=1)

folds_files = [("train_test_split/surprise_train.csv", "train_test_split/surprise_test.csv")]

data = Dataset.load_from_folds(folds_files, reader=reader)
pkf = PredefinedKFold()

baseline = BaselineOnly()

for trainset, testset in pkf.split(data):

    # train and test algorithm.
    baseline.fit(trainset)
    predictions = baseline.test(testset)

    # Compute and print Root Mean Squared Error
    accuracy.mse(predictions, verbose=True)
# Out:
# Estimating biases using als...
# MSE: 0.0869

# %% [markdown]
# ## Test an SVD algorithm
# Uses user/game latent factors to predict new game ratings

# %%
svd = SVD(n_factors=10)

for trainset, testset in pkf.split(data):

    # train and test algorithm.
    svd.fit(trainset)
    predictions = svd.test(testset)

    # Compute and print Root Mean Squared Error
    accuracy.mse(predictions, verbose=True)
# Out:
# MSE: 0.0862
