# %% [markdown]
# # Game RecSys Model Building/Evaluation
# Notebook for building and evaluating ML models of the game recommendation systems

# %% [markdown]
# ## Load and format data

# %%
import numpy as np
import pandas as pd
from tqdm import tqdm_notebook as tqdm
import matplotlib.pyplot as plt
# %matplotlib inline

import seaborn as sns
sns.set()

# %% [markdown]
# ### Load user-game ratings data
# #### Training data

# %%
X_train = pd.read_csv("train_test_split/X_train_3k.csv")
X_train = X_train.set_index("Unnamed: 0")
y_train = pd.read_csv("train_test_split/y_train_3k.csv")
y_train = y_train.set_index("Unnamed: 0")
# join and reset index
train_df = pd.merge(X_train, y_train, left_index=True, right_index=True, validate="1:1")
train_df = train_df.reset_index(drop=True)[["user_id", "item_id", "recommend"]].copy()

# %%
train_df.head()
# Out:
#              user_id  item_id  recommend
# 0          Drewmatic     8930          1
# 1  76561198080148447   377160          1
# 2   AleksoSmeksoHere   342380          1
# 3            gaboqse   108800          0
# 4            piedude   215470          1

# %% [markdown]
# #### Test data

# %%
X_test = pd.read_csv("train_test_split/X_test_3k.csv")
X_test = X_test.set_index("Unnamed: 0")
y_test = pd.read_csv("train_test_split/y_test_3k.csv")
y_test = y_test.set_index("Unnamed: 0")
# join and reset index
test_df = pd.merge(X_test, y_test, left_index=True, right_index=True, validate="1:1")
test_df = test_df.reset_index(drop=True)[["user_id", "item_id", "recommend"]].copy()

# %%
test_df.head()
# Out:
#                       user_id  item_id  recommend
# 0                 sickbubblez   386360          1
# 1  GetALifeStopLookingAtMyUrl     4000          1
# 2                 kineticvine     1250          1
# 3                   LeoNoHomo   200210          1
# 4                itsdandytime     4000          1

# %% [markdown]
# ### Load game metadata

# %%
game_meta = pd.read_csv("train_test_split/processed_metadata.csv").rename(
    columns={"Unnamed: 0":"item_id"}).set_index("item_id")
game_meta.head()
# Out:
#          early_access  metascore  price  sentiment  Action  Adventure  \
# item_id
# 10                  0       88.0   9.99          3     1.0        0.0
# 20                  0        NaN   4.99          2     1.0        0.0
# 30                  0       79.0   4.99          2     1.0        0.0
# 50                  0        NaN   4.99          2     1.0        0.0
# 60                  0        NaN   4.99          1     1.0        0.0
#
#          Animation &amp; Modeling  Audio Production  Casual  \
# item_id
# 10                            0.0               0.0     0.0
# 20                            0.0               0.0     0.0
# 30                            0.0               0.0     0.0
# 50                            0.0               0.0     0.0
# 60                            0.0               0.0     0.0
#
#          Design &amp; Illustration  ...  Stats  Steam Achievements  \
# item_id                             ...
# 10                             0.0  ...    0.0                 0.0
# 20                             0.0  ...    0.0                 0.0
# 30                             0.0  ...    0.0                 0.0
# 50                             0.0  ...    0.0                 0.0
# 60                             0.0  ...    0.0                 0.0
#
#          Steam Cloud  Steam Leaderboards  Steam Trading Cards  \
# item_id
# 10               0.0                 0.0                  0.0
# 20               0.0                 0.0                  0.0
# 30               0.0                 0.0                  0.0
# 50               0.0                 0.0                  0.0
# 60               0.0                 0.0                  0.0
#
#          Steam Turn Notifications  Steam Workshop  SteamVR Collectibles  \
# item_id
# 10                            0.0             0.0                   0.0
# 20                            0.0             0.0                   0.0
# 30                            0.0             0.0                   0.0
# 50                            0.0             0.0                   0.0
# 60                            0.0             0.0                   0.0
#
#          Tracked Motion Controllers  Valve Anti-Cheat enabled
# item_id
# 10                              0.0                       1.0
# 20                              0.0                       1.0
# 30                              0.0                       1.0
# 50                              0.0                       1.0
# 60                              0.0                       1.0
#
# [5 rows x 62 columns]

# %% [markdown]
# ## Content-based filtering (CBF)

# %% [markdown]
# ### Compute game-game similarity matrix

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
# fill NaN:s with column mean values
game_meta_cbf = game_meta.fillna(game_meta.mean())

# normalize values in the metascore, price, and sentiment columns to a range of 0 - 1
scaler = MinMaxScaler()
scaled_cbf = scaler.fit_transform(game_meta_cbf[["metascore", "price", "sentiment"]])
game_meta_cbf[["metascore", "price", "sentiment"]] = scaled_cbf
game_meta_cbf.head()
# Out:
#          early_access  metascore     price  sentiment  Action  Adventure  \
# item_id
# 10                  0   0.888889  0.012318   1.000000     1.0        0.0
# 20                  0   0.735917  0.005835   0.833333     1.0        0.0
# 30                  0   0.763889  0.005835   0.833333     1.0        0.0
# 50                  0   0.735917  0.005835   0.833333     1.0        0.0
# 60                  0   0.735917  0.005835   0.666667     1.0        0.0
#
#          Animation &amp; Modeling  Audio Production  Casual  \
# item_id
# 10                            0.0               0.0     0.0
# 20                            0.0               0.0     0.0
# 30                            0.0               0.0     0.0
# 50                            0.0               0.0     0.0
# 60                            0.0               0.0     0.0
#
#          Design &amp; Illustration  ...  Stats  Steam Achievements  \
# item_id                             ...
# 10                             0.0  ...    0.0                 0.0
# 20                             0.0  ...    0.0                 0.0
# 30                             0.0  ...    0.0                 0.0
# 50                             0.0  ...    0.0                 0.0
# 60                             0.0  ...    0.0                 0.0
#
#          Steam Cloud  Steam Leaderboards  Steam Trading Cards  \
# item_id
# 10               0.0                 0.0                  0.0
# 20               0.0                 0.0                  0.0
# 30               0.0                 0.0                  0.0
# 50               0.0                 0.0                  0.0
# 60               0.0                 0.0                  0.0
#
#          Steam Turn Notifications  Steam Workshop  SteamVR Collectibles  \
# item_id
# 10                            0.0             0.0                   0.0
# 20                            0.0             0.0                   0.0
# 30                            0.0             0.0                   0.0
# 50                            0.0             0.0                   0.0
# 60                            0.0             0.0                   0.0
#
#          Tracked Motion Controllers  Valve Anti-Cheat enabled
# item_id
# 10                              0.0                       1.0
# 20                              0.0                       1.0
# 30                              0.0                       1.0
# 50                              0.0                       1.0
# 60                              0.0                       1.0
#
# [5 rows x 62 columns]

# %%
# create the similarity matrix using the Pearson correlation coefficient
game_similarity_matrix = game_meta_cbf.T.corr(method="pearson")
game_similarity_matrix.head()
# Out:
# item_id    10        20        30        50        60        70        80      \
# item_id
# 10       1.000000  0.995876  0.996523  0.886343  0.987870  0.903771  0.874333
# 20       0.995876  1.000000  0.999913  0.890223  0.996834  0.897767  0.882236
# 30       0.996523  0.999913  1.000000  0.890122  0.996925  0.898915  0.881176
# 50       0.886343  0.890223  0.890122  1.000000  0.887474  0.992939  0.997260
# 60       0.987870  0.996834  0.996925  0.887474  1.000000  0.891217  0.878529
#
# item_id    130       220       240     ...    461560    462930    464780  \
# item_id                                ...
# 10       0.595771  0.345255  0.666608  ...  0.168448  0.057541  0.271566
# 20       0.567854  0.320196  0.664101  ...  0.136324  0.035855  0.230239
# 30       0.570038  0.322738  0.664492  ...  0.139112  0.038510  0.233858
# 50       0.768895  0.423638  0.576950  ...  0.284290  0.167338  0.424495
# 60       0.545535  0.304708  0.658711  ...  0.115835  0.026715  0.203760
#
# item_id    466910    480631    485380    485890    495890    498240    512540
# item_id
# 10       0.398367  0.084417  0.271758  0.169150  0.221772  0.200073  0.403472
# 20       0.376656  0.062280  0.230463  0.138871  0.184451  0.166047  0.409524
# 30       0.378615  0.065606  0.234082  0.142606  0.187232  0.169551  0.409397
# 50       0.321012  0.224906  0.424705  0.327764  0.337321  0.348091  0.466629
# 60       0.361192  0.056281  0.203988  0.125749  0.157876  0.147367  0.412284
#
# [5 rows x 1185 columns]

# %% [markdown]
# ### CBF algorithm
# To calculate the rating score for a particulair user-game pair, this algorithm does the following:
# 1. obtain the list of other game id:s this user has rated
# 2. obtain the similarity scores of those games to the game of interest
# 3. calculate the rating for the game of interest using the following equation: $$r_{ik}=\frac{\sum_{j\neq k}{r_{ij}s_{jk}}}{\sum_{j\neq k}{s_{jk}}}$$ where $r_{ik}$, $r_{ij}$, and $s_{jk}$ are the desired rating of user **i** for game **k**, rating of game **j** by user **i**, and the similarity of game **j** with game **k** respectively.
# 4. If no similarities are available for calculating $r_{ik}$, the algorithm just returns the average rating of game **k** by all users

# %%
# CBF algorithm
def cbf_rate(user, item, data, similarity):
    """calculates the predicted rating for a game
    by a user
    data - training df
    similarity - game similarity matrix
    avg_ratings - average game ratings"""
    # compute average ratings in the training set
    r_avg = np.average(data[data["item_id"] == item]["recommend"].values)
    #print("average rating: %.2f" % (r_avg))
    # obtain similarity scores for the game
    try:
        game_s = similarity[item].to_frame()
    except KeyError:
        # no similarity data available, return average rating
        #print("No similarity data available, using average rating...")
        return r_avg
    # obtain ratings by this user for all items except the item of interest
    game_r = data[(data["user_id"] == user) & 
                  (data["item_id"] != item)][["item_id", "recommend"]].copy().set_index("item_id")
    #print("Available ratings data:")
    #print(game_r)
    if len(game_r) > 0:
        # ratings data available, compute rating
        game_r_s = game_r.merge(game_s, left_index=True, right_index=True)
        if len(game_r_s) > 0:
            # there is available similarity data
            ratings, sims = game_r_s.iloc[:,0].values, game_r_s.iloc[:,1].values
            #print(ratings, sims)
            r = np.dot(ratings, sims) / np.sum(sims)
            #print(r)
            return r
        else:
            # no available similarity data, return average rating
            return r_avg
    else:
        # ratings data not available, return average rating
        return r_avg
    
def cbf_predict(data, training_data, similarity):
    """predicts ratings for all user-item pairs in the
    passed dataset - data
    similarity - game similarity matrix"""
    user_item = data[["user_id", "item_id"]]
    with tqdm(total=len(user_item)) as pbar:
        for idx, row in user_item.iterrows():
            r = cbf_rate(row["user_id"], row["item_id"], training_data, similarity)
            user_item.loc[idx, "r_pred"] = r
            pbar.update(1)
    return user_item

# %% [markdown]
# ### CBF evaluation
# Evaluate the CBF algorithm on both the training and test sets and compare with the baseline models

# %%
from sklearn.metrics import mean_squared_error

# %%
# make predictions and compute MSE on the training set
train_cbf_pred = cbf_predict(train_df, train_df, game_similarity_matrix)
train_cbf_mse = mean_squared_error(train_df["recommend"], train_cbf_pred["r_pred"])
print("MSE: %.4f" %(train_cbf_mse))
# Out:
# HBox(children=(IntProgress(value=0, max=24969), HTML(value='')))
# MSE: 0.1284

# %%
# make predictions and compute MSE on the test set
test_cbf_pred = cbf_predict(test_df, train_df, game_similarity_matrix)
test_cbf_mse = mean_squared_error(test_df["recommend"], test_cbf_pred["r_pred"])
print("MSE: %.4f" %(test_cbf_mse))
# Out:
# HBox(children=(IntProgress(value=0, max=8323), HTML(value='')))
# MSE: 0.1181

# %% [markdown]
# Not better than the baseline model!

# %% [markdown]
# ## Collaborative filtering (CF) using deep learning

# %% [markdown]
# ### Assemble the full game metadata set
# Include also the game ids without any metadata available. For these algorithms we cannot have missing values

# %%
game_ids = pd.Series(train_df["item_id"].unique(), name="item_id").to_frame().set_index("item_id")
full_meta = pd.merge(game_ids, game_meta, how="left", left_index=True, right_index=True)
full_meta.shape
# Out:
# (1346, 62)

# %% [markdown]
# #### Fill NaN:s and normalize values in `metascore`, `price`, and `sentiment` columns

# %%
# fill NaN:s with column mean values
full_meta.fillna(full_meta.mean(), inplace=True)

# normalize values in the 2 columns
scaler = MinMaxScaler()
scaled = scaler.fit_transform(full_meta[["metascore", "price", "sentiment"]])
full_meta[["metascore", "price", "sentiment"]] = scaled

full_meta.head()
# Out:
#          early_access  metascore     price  sentiment    Action  Adventure  \
# item_id
# 8930         0.000000   0.916667  0.038251   1.000000  0.000000   0.000000
# 377160       0.000000   0.833333  0.038251   0.500000  0.000000   0.000000
# 342380       0.050633   0.735917  0.021977   0.764838  0.594991   0.303972
# 108800       0.000000   0.735917  0.038251   0.833333  1.000000   0.000000
# 215470       0.000000   0.597222  0.009725   0.666667  1.000000   0.000000
#
#          Animation &amp; Modeling  Audio Production    Casual  \
# item_id
# 8930                     0.000000          0.000000  0.000000
# 377160                   0.000000          0.000000  0.000000
# 342380                   0.004318          0.000864  0.124352
# 108800                   0.000000          0.000000  0.000000
# 215470                   0.000000          0.000000  0.000000
#
#          Design &amp; Illustration  ...     Stats  Steam Achievements  \
# item_id                             ...
# 8930                      0.000000  ...  0.000000            1.000000
# 377160                    0.000000  ...  0.000000            1.000000
# 342380                    0.001727  ...  0.119898            0.637755
# 108800                    0.000000  ...  0.000000            0.000000
# 215470                    0.000000  ...  0.000000            1.000000
#
#          Steam Cloud  Steam Leaderboards  Steam Trading Cards  \
# item_id
# 8930        1.000000            0.000000              1.00000
# 377160      1.000000            0.000000              0.00000
# 342380      0.417517            0.213435              0.52551
# 108800      0.000000            0.000000              0.00000
# 215470      0.000000            0.000000              1.00000
#
#          Steam Turn Notifications  Steam Workshop  SteamVR Collectibles  \
# item_id
# 8930                     0.000000        0.000000               0.00000
# 377160                   0.000000        0.000000               0.00000
# 342380                   0.002551        0.142857               0.00085
# 108800                   0.000000        0.000000               0.00000
# 215470                   0.000000        0.000000               0.00000
#
#          Tracked Motion Controllers  Valve Anti-Cheat enabled
# item_id
# 8930                       0.000000                  0.000000
# 377160                     0.000000                  0.000000
# 342380                     0.005952                  0.064626
# 108800                     0.000000                  0.000000
# 215470                     0.000000                  1.000000
#
# [5 rows x 62 columns]

# %% [markdown]
# ### Recreate user-item indexes (needed for embedding layers)

# %%
# create new indexes for unique users/items
unique_users = pd.Series(train_df["user_id"].unique(),
                         name="user_name").to_frame().reset_index().rename(columns={"index":"user_idx"})

unique_items = pd.Series(train_df["item_id"].unique(),
                         name="original_id").to_frame().reset_index().rename(columns={"index":"item_idx"})

# %%
# join back on training/test sets
def assemble_reindexed_dataset(df):
    # join back on training/test sets
    df_user_idx = pd.merge(df, unique_users, how="left",
                              left_on="user_id",
                              right_on="user_name").drop(columns="user_name")
    df_idx = pd.merge(df_user_idx, unique_items, how="left",
                        left_on="item_id",
                        right_on="original_id").drop(columns="original_id")
    # join with game metadata
    df_full_idx = pd.merge(df_idx, full_meta, how="left",
                              left_on="item_id",
                              right_on="item_id").iloc[:,2:]
    return df_full_idx

# %%
train_full_idx = assemble_reindexed_dataset(train_df)
test_full_idx = assemble_reindexed_dataset(test_df)

# %%
train_full_idx.head()
# Out:
#    recommend  user_idx  item_idx  early_access  metascore     price  \
# 0          1         0         0      0.000000   0.916667  0.038251
# 1          1         1         1      0.000000   0.833333  0.038251
# 2          1         2         2      0.050633   0.735917  0.021977
# 3          0         3         3      0.000000   0.735917  0.038251
# 4          1         4         4      0.000000   0.597222  0.009725
#
#    sentiment    Action  Adventure  Animation &amp; Modeling  ...     Stats  \
# 0   1.000000  0.000000   0.000000                  0.000000  ...  0.000000
# 1   0.500000  0.000000   0.000000                  0.000000  ...  0.000000
# 2   0.764838  0.594991   0.303972                  0.004318  ...  0.119898
# 3   0.833333  1.000000   0.000000                  0.000000  ...  0.000000
# 4   0.666667  1.000000   0.000000                  0.000000  ...  0.000000
#
#    Steam Achievements  Steam Cloud  Steam Leaderboards  Steam Trading Cards  \
# 0            1.000000     1.000000            0.000000              1.00000
# 1            1.000000     1.000000            0.000000              0.00000
# 2            0.637755     0.417517            0.213435              0.52551
# 3            0.000000     0.000000            0.000000              0.00000
# 4            1.000000     0.000000            0.000000              1.00000
#
#    Steam Turn Notifications  Steam Workshop  SteamVR Collectibles  \
# 0                  0.000000        0.000000               0.00000
# 1                  0.000000        0.000000               0.00000
# 2                  0.002551        0.142857               0.00085
# 3                  0.000000        0.000000               0.00000
# 4                  0.000000        0.000000               0.00000
#
#    Tracked Motion Controllers  Valve Anti-Cheat enabled
# 0                    0.000000                  0.000000
# 1                    0.000000                  0.000000
# 2                    0.005952                  0.064626
# 3                    0.000000                  0.000000
# 4                    0.000000                  1.000000
#
# [5 rows x 65 columns]

# %% [markdown]
# ### Format training and test data for keras

# %%
# get the data
X_train = train_full_idx.iloc[:, [1, 2]].values
y_train = train_full_idx.iloc[:, 0].values
X_test = test_full_idx.iloc[:, [1, 2]].values
y_test = test_full_idx.iloc[:, [0]].values

# format the training data
X_train_u = X_train[:,0].reshape(-1,1)
X_train_i = X_train[:,1].reshape(-1,1)
y_train = y_train.reshape(-1,1)
# format the test data
X_test_u = X_test[:,0].reshape(-1,1)
X_test_i = X_test[:,1].reshape(-1,1)
y_test = y_test.reshape(-1,1)

# %% [markdown]
# ### Basic user-item embedding model

# %%
from keras.models import Model
from keras.layers import Input, Embedding, Dense, Flatten, Activation, BatchNormalization
from keras.layers import concatenate, dot
from keras.regularizers import l2
from keras.callbacks import ModelCheckpoint, ReduceLROnPlateau, EarlyStopping
import keras.backend as K
# Out:
# Using TensorFlow backend.

# %% [markdown]
# #### Build the model

# %%
# define model variables
n_users = len(unique_users)
n_items = len(unique_items)
embedding_size_users = 16
embedding_size_items = 16

# create user path
user_input = Input(shape=(1,), name="user")
user_embeddings = Embedding(n_users, 
                            embedding_size_users, 
                            embeddings_regularizer=l2(0.005),
                            embeddings_initializer="glorot_normal",
                            name="user_embeddings")(user_input)
user_flat = Flatten(name="user_flattened")(user_embeddings)

# create item path
item_input = Input(shape=(1,), name="item")
item_embeddings = Embedding(n_items, 
                            embedding_size_items,
                            embeddings_regularizer=l2(0.005),
                            embeddings_initializer="glorot_normal",
                            name="item_embeddings")(item_input)
item_flat = Flatten(name="item_flattened")(item_embeddings)

# combine the two paths
prod = dot([user_flat, item_flat], 1, name="predicted_ratings")
# normalize input and constrain outputs to 0 - 1 range
prod = BatchNormalization()(prod)
output = Activation("sigmoid")(prod)

# compile the model
cf_model = Model(inputs=[user_input, item_input], outputs=output)
cf_model.compile("adam", loss="mse", metrics=["mse"])

# summarize the model
cf_model.summary()
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# user (InputLayer)               (None, 1)            0
# __________________________________________________________________________________________________
# item (InputLayer)               (None, 1)            0
# __________________________________________________________________________________________________
# user_embeddings (Embedding)     (None, 1, 16)        110496      user[0][0]
# __________________________________________________________________________________________________
# item_embeddings (Embedding)     (None, 1, 16)        21536       item[0][0]
# __________________________________________________________________________________________________
# user_flattened (Flatten)        (None, 16)           0           user_embeddings[0][0]
# __________________________________________________________________________________________________
# item_flattened (Flatten)        (None, 16)           0           item_embeddings[0][0]
# __________________________________________________________________________________________________
# predicted_ratings (Dot)         (None, 1)            0           user_flattened[0][0]
#                                                                  item_flattened[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 1)            4           predicted_ratings[0][0]
# __________________________________________________________________________________________________
# activation_5 (Activation)       (None, 1)            0           batch_normalization_4[0][0]
# ==================================================================================================
# Total params: 132,036
# Trainable params: 132,034
# Non-trainable params: 2
# __________________________________________________________________________________________________

# %% [markdown]
# #### Train the model using CV

# %%
# define callbacks
reduce_lr = ReduceLROnPlateau(patience=5, verbose=1)
early_stop = EarlyStopping(min_delta=0.0001, patience=10, verbose=1)

# train model for a few epochs
cf_model.fit(x={"user":X_train_u, "item":X_train_i}, 
              y=y_train, 
              batch_size=32, 
              epochs=50, 
              verbose=2, 
              validation_split=0.2,
              callbacks=[reduce_lr, early_stop]
             )
# Out:
# Train on 19975 samples, validate on 4994 samples
# Epoch 1/50
#  - 4s - loss: 0.2107 - mean_squared_error: 0.2023 - val_loss: 0.1690 - val_mean_squared_error: 0.1690
# Epoch 2/50
#  - 3s - loss: 0.1447 - mean_squared_error: 0.1447 - val_loss: 0.1352 - val_mean_squared_error: 0.1352
# Epoch 3/50
#  - 3s - loss: 0.1209 - mean_squared_error: 0.1209 - val_loss: 0.1220 - val_mean_squared_error: 0.1220
# Epoch 4/50
#  - 3s - loss: 0.1111 - mean_squared_error: 0.1111 - val_loss: 0.1168 - val_mean_squared_error: 0.1168
# Epoch 5/50
#  - 2s - loss: 0.1069 - mean_squared_error: 0.1069 - val_loss: 0.1148 - val_mean_squared_error: 0.1148
# Epoch 6/50
#  - 2s - loss: 0.1051 - mean_squared_error: 0.1051 - val_loss: 0.1141 - val_mean_squared_error: 0.1141
# Epoch 7/50
#  - 2s - loss: 0.1044 - mean_squared_error: 0.1044 - val_loss: 0.1140 - val_mean_squared_error: 0.1140
# Epoch 8/50
#  - 2s - loss: 0.1041 - mean_squared_error: 0.1041 - val_loss: 0.1140 - val_mean_squared_error: 0.1140
# Epoch 9/50
#  - 2s - loss: 0.1040 - mean_squared_error: 0.1040 - val_loss: 0.1140 - val_mean_squared_error: 0.1140
# Epoch 10/50
#  - 2s - loss: 0.1040 - mean_squared_error: 0.1040 - val_loss: 0.1141 - val_mean_squared_error: 0.1141
# Epoch 11/50
#  - 2s - loss: 0.1040 - mean_squared_error: 0.1040 - val_loss: 0.1141 - val_mean_squared_error: 0.1141
# Epoch 12/50
#  - 2s - loss: 0.1040 - mean_squared_error: 0.1040 - val_loss: 0.1141 - val_mean_squared_error: 0.1141
#
# Epoch 00012: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# Epoch 13/50
#  - 3s - loss: 0.1040 - mean_squared_error: 0.1040 - val_loss: 0.1141 - val_mean_squared_error: 0.1141
# Epoch 14/50
#  - 3s - loss: 0.1040 - mean_squared_error: 0.1040 - val_loss: 0.1141 - val_mean_squared_error: 0.1141
# Epoch 15/50
#  - 2s - loss: 0.1040 - mean_squared_error: 0.1040 - val_loss: 0.1141 - val_mean_squared_error: 0.1141
# Epoch 16/50
#  - 3s - loss: 0.1040 - mean_squared_error: 0.1040 - val_loss: 0.1141 - val_mean_squared_error: 0.1141
# Epoch 17/50
#  - 2s - loss: 0.1040 - mean_squared_error: 0.1040 - val_loss: 0.1141 - val_mean_squared_error: 0.1141
#
# Epoch 00017: ReduceLROnPlateau reducing learning rate to 1.0000000474974514e-05.
# Epoch 00017: early stopping

# %% [markdown]
# #### Evaluate performance on the test set

# %%
# evaluate on the test set
cf_model.evaluate(x={"user":X_test_u, "item":X_test_i}, y=y_test)
# Out:
# 8323/8323 [==============================] - ETA:  - ETA:  - ETA:  - 0s 15us/step
# [0.10103453326792199, 0.10103453326792199]

# %%
# inspect the predictions made by the model
predictions = cf_model.predict(x={"user":X_test_u, "item":X_test_i})
print(np.min(predictions), np.max(predictions))

# %% [markdown]
# The model has learned to always output the same value. Not very usefull...

# %% [markdown]
# ### Deep learning of user-item preferences

# %% [markdown]
# #### Build the model

# %%
from keras.layers import Dropout
from keras.optimizers import Adam

# %%
# define model variables
n_users = len(unique_users)
n_items = len(unique_items)
embedding_size_users = 16
embedding_size_items = 16
l2_param = 0.05
dropout_rate = 0.5

# create user path
user_input = Input(shape=(1,), name="user")
user_embeddings = Embedding(n_users, 
                            embedding_size_users, 
                            embeddings_regularizer=l2(l2_param),
                            embeddings_initializer="glorot_normal",
                            name="user_embeddings")(user_input)
user_flat = Flatten(name="user_flattened")(user_embeddings)

# create item path
item_input = Input(shape=(1,), name="item")
item_embeddings = Embedding(n_items, 
                            embedding_size_items,
                            embeddings_regularizer=l2(l2_param),
                            embeddings_initializer="glorot_normal",
                            name="item_embeddings")(item_input)
item_flat = Flatten(name="item_flattened")(item_embeddings)

# combine the two paths
user_item = concatenate([user_flat, item_flat], name="user_item")
user_item = Dropout(dropout_rate)(user_item)

# hidden layer 1
interaction = Dense(32, kernel_regularizer=l2(l2_param), bias_regularizer=l2(l2_param))(user_item)
interaction = BatchNormalization()(interaction)
interaction = Activation("relu")(interaction)
interaction = Dropout(dropout_rate)(interaction)

# hidden layer 2
interaction = Dense(32, kernel_regularizer=l2(l2_param), bias_regularizer=l2(l2_param))(interaction)
interaction = BatchNormalization()(interaction)
interaction = Activation("relu")(interaction)

# output layer
pred = Dense(1, activation="sigmoid")(interaction)

# optimizer
opt = Adam(lr=0.0001)

# compile the model
dcf_model = Model(inputs=[user_input, item_input], outputs=pred)
dcf_model.compile(opt, loss="mse", metrics=["mse"])
dcf_model.summary()
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# user (InputLayer)               (None, 1)            0
# __________________________________________________________________________________________________
# item (InputLayer)               (None, 1)            0
# __________________________________________________________________________________________________
# user_embeddings (Embedding)     (None, 1, 16)        110496      user[0][0]
# __________________________________________________________________________________________________
# item_embeddings (Embedding)     (None, 1, 16)        21536       item[0][0]
# __________________________________________________________________________________________________
# user_flattened (Flatten)        (None, 16)           0           user_embeddings[0][0]
# __________________________________________________________________________________________________
# item_flattened (Flatten)        (None, 16)           0           item_embeddings[0][0]
# __________________________________________________________________________________________________
# user_item (Concatenate)         (None, 32)           0           user_flattened[0][0]
#                                                                  item_flattened[0][0]
# __________________________________________________________________________________________________
# dropout_48 (Dropout)            (None, 32)           0           user_item[0][0]
# __________________________________________________________________________________________________
# dense_83 (Dense)                (None, 32)           1056        dropout_48[0][0]
# __________________________________________________________________________________________________
# batch_normalization_51 (BatchNo (None, 32)           128         dense_83[0][0]
# __________________________________________________________________________________________________
# activation_63 (Activation)      (None, 32)           0           batch_normalization_51[0][0]
# __________________________________________________________________________________________________
# dropout_49 (Dropout)            (None, 32)           0           activation_63[0][0]
# __________________________________________________________________________________________________
# dense_84 (Dense)                (None, 32)           1056        dropout_49[0][0]
# __________________________________________________________________________________________________
# batch_normalization_52 (BatchNo (None, 32)           128         dense_84[0][0]
# __________________________________________________________________________________________________
# activation_64 (Activation)      (None, 32)           0           batch_normalization_52[0][0]
# __________________________________________________________________________________________________
# dense_85 (Dense)                (None, 1)            33          activation_64[0][0]
# ==================================================================================================
# Total params: 134,433
# Trainable params: 134,305
# Non-trainable params: 128
# __________________________________________________________________________________________________

# %% [markdown]
# #### Train the model using CV

# %%
# define callbacks
reduce_lr = ReduceLROnPlateau("val_mean_squared_error", patience=5, verbose=1)
early_stop = EarlyStopping("val_mean_squared_error", min_delta=0.0001, patience=10, verbose=1)

# train model for a few epochs
dcf_model.fit(x={"user":X_train_u, "item":X_train_i}, 
              y=y_train, 
              batch_size=32, 
              epochs=50, 
              verbose=2, 
              validation_split=0.2,
              callbacks=[reduce_lr, early_stop]
             )
# Out:
# Train on 19975 samples, validate on 4994 samples
# Epoch 1/50
#  - 11s - loss: 3.4702 - mean_squared_error: 0.1950 - val_loss: 2.0965 - val_mean_squared_error: 0.1796
# Epoch 2/50
#  - 4s - loss: 1.4955 - mean_squared_error: 0.1302 - val_loss: 1.0798 - val_mean_squared_error: 0.1414
# Epoch 3/50
#  - 4s - loss: 0.7818 - mean_squared_error: 0.1120 - val_loss: 0.5786 - val_mean_squared_error: 0.1266
# Epoch 4/50
#  - 4s - loss: 0.4204 - mean_squared_error: 0.1072 - val_loss: 0.3227 - val_mean_squared_error: 0.1202
# Epoch 5/50
#  - 4s - loss: 0.2407 - mean_squared_error: 0.1047 - val_loss: 0.2016 - val_mean_squared_error: 0.1171
# Epoch 6/50
#  - 4s - loss: 0.1591 - mean_squared_error: 0.1036 - val_loss: 0.1484 - val_mean_squared_error: 0.1147
# Epoch 7/50
#  - 4s - loss: 0.1250 - mean_squared_error: 0.1024 - val_loss: 0.1256 - val_mean_squared_error: 0.1111
# Epoch 8/50
#  - 4s - loss: 0.1124 - mean_squared_error: 0.1017 - val_loss: 0.1169 - val_mean_squared_error: 0.1090
# Epoch 9/50
#  - 4s - loss: 0.1071 - mean_squared_error: 0.0999 - val_loss: 0.1125 - val_mean_squared_error: 0.1057
# Epoch 10/50
#  - 4s - loss: 0.1052 - mean_squared_error: 0.0982 - val_loss: 0.1117 - val_mean_squared_error: 0.1045
# Epoch 11/50
#  - 4s - loss: 0.1044 - mean_squared_error: 0.0970 - val_loss: 0.1117 - val_mean_squared_error: 0.1048
# Epoch 12/50
#  - 4s - loss: 0.1040 - mean_squared_error: 0.0965 - val_loss: 0.1115 - val_mean_squared_error: 0.1048
# Epoch 13/50
#  - 4s - loss: 0.1039 - mean_squared_error: 0.0960 - val_loss: 0.1117 - val_mean_squared_error: 0.1036
# Epoch 14/50
#  - 4s - loss: 0.1032 - mean_squared_error: 0.0937 - val_loss: 0.1126 - val_mean_squared_error: 0.1031
# Epoch 15/50
#  - 4s - loss: 0.1034 - mean_squared_error: 0.0920 - val_loss: 0.1134 - val_mean_squared_error: 0.1020
# Epoch 16/50
#  - 4s - loss: 0.1025 - mean_squared_error: 0.0893 - val_loss: 0.1144 - val_mean_squared_error: 0.1013
# Epoch 17/50
#  - 4s - loss: 0.1018 - mean_squared_error: 0.0875 - val_loss: 0.1143 - val_mean_squared_error: 0.1006
# Epoch 18/50
#  - 4s - loss: 0.1008 - mean_squared_error: 0.0859 - val_loss: 0.1152 - val_mean_squared_error: 0.1006
# Epoch 19/50
#  - 4s - loss: 0.0991 - mean_squared_error: 0.0836 - val_loss: 0.1166 - val_mean_squared_error: 0.1008
# Epoch 20/50
#  - 4s - loss: 0.0980 - mean_squared_error: 0.0817 - val_loss: 0.1175 - val_mean_squared_error: 0.1014
# Epoch 21/50
#  - 4s - loss: 0.0985 - mean_squared_error: 0.0821 - val_loss: 0.1160 - val_mean_squared_error: 0.1001
# Epoch 22/50
#  - 4s - loss: 0.0982 - mean_squared_error: 0.0820 - val_loss: 0.1162 - val_mean_squared_error: 0.1001
# Epoch 23/50
#  - 4s - loss: 0.0973 - mean_squared_error: 0.0810 - val_loss: 0.1170 - val_mean_squared_error: 0.1006
# Epoch 24/50
#  - 4s - loss: 0.0970 - mean_squared_error: 0.0802 - val_loss: 0.1178 - val_mean_squared_error: 0.1006
# Epoch 25/50
#  - 4s - loss: 0.0962 - mean_squared_error: 0.0794 - val_loss: 0.1180 - val_mean_squared_error: 0.1010
# Epoch 26/50
#  - 4s - loss: 0.0960 - mean_squared_error: 0.0789 - val_loss: 0.1174 - val_mean_squared_error: 0.1004
#
# Epoch 00026: ReduceLROnPlateau reducing learning rate to 9.999999747378752e-06.
# Epoch 27/50
#  - 4s - loss: 0.0907 - mean_squared_error: 0.0742 - val_loss: 0.1163 - val_mean_squared_error: 0.1002
# Epoch 28/50
#  - 4s - loss: 0.0899 - mean_squared_error: 0.0741 - val_loss: 0.1155 - val_mean_squared_error: 0.1000
# Epoch 29/50
#  - 5s - loss: 0.0878 - mean_squared_error: 0.0726 - val_loss: 0.1149 - val_mean_squared_error: 0.0999
# Epoch 30/50
#  - 5s - loss: 0.0861 - mean_squared_error: 0.0713 - val_loss: 0.1144 - val_mean_squared_error: 0.0998
# Epoch 31/50
#  - 4s - loss: 0.0862 - mean_squared_error: 0.0718 - val_loss: 0.1138 - val_mean_squared_error: 0.0996
# Epoch 32/50
#  - 4s - loss: 0.0858 - mean_squared_error: 0.0717 - val_loss: 0.1134 - val_mean_squared_error: 0.0996
# Epoch 33/50
#  - 4s - loss: 0.0858 - mean_squared_error: 0.0721 - val_loss: 0.1131 - val_mean_squared_error: 0.0995
# Epoch 34/50
#  - 4s - loss: 0.0855 - mean_squared_error: 0.0721 - val_loss: 0.1130 - val_mean_squared_error: 0.0995
# Epoch 35/50
#  - 4s - loss: 0.0841 - mean_squared_error: 0.0707 - val_loss: 0.1128 - val_mean_squared_error: 0.0994
# Epoch 36/50
#  - 4s - loss: 0.0838 - mean_squared_error: 0.0704 - val_loss: 0.1129 - val_mean_squared_error: 0.0995
# Epoch 37/50
#  - 4s - loss: 0.0831 - mean_squared_error: 0.0697 - val_loss: 0.1130 - val_mean_squared_error: 0.0996
# Epoch 38/50
#  - 4s - loss: 0.0833 - mean_squared_error: 0.0699 - val_loss: 0.1128 - val_mean_squared_error: 0.0995
# Epoch 39/50
#  - 4s - loss: 0.0822 - mean_squared_error: 0.0689 - val_loss: 0.1128 - val_mean_squared_error: 0.0997
# Epoch 40/50
#  - 4s - loss: 0.0824 - mean_squared_error: 0.0692 - val_loss: 0.1129 - val_mean_squared_error: 0.0996
#
# Epoch 00040: ReduceLROnPlateau reducing learning rate to 9.999999747378752e-07.
# Epoch 41/50
#  - 4s - loss: 0.0810 - mean_squared_error: 0.0678 - val_loss: 0.1129 - val_mean_squared_error: 0.0996
# Epoch 42/50
#  - 4s - loss: 0.0807 - mean_squared_error: 0.0675 - val_loss: 0.1129 - val_mean_squared_error: 0.0997
# Epoch 43/50
#  - 4s - loss: 0.0812 - mean_squared_error: 0.0680 - val_loss: 0.1129 - val_mean_squared_error: 0.0997
# Epoch 44/50
#  - 4s - loss: 0.0807 - mean_squared_error: 0.0675 - val_loss: 0.1129 - val_mean_squared_error: 0.0997
# Epoch 45/50
#  - 4s - loss: 0.0816 - mean_squared_error: 0.0684 - val_loss: 0.1129 - val_mean_squared_error: 0.0997
#
# Epoch 00045: ReduceLROnPlateau reducing learning rate to 9.999999974752428e-08.
# Epoch 00045: early stopping

# %% [markdown]
# #### Evaluate performance on the test set

# %%
# evaluate on the test set
dcf_model.evaluate(x={"user":X_test_u, "item":X_test_i}, y=y_test)
# Out:
# 8323/8323 [==============================] - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - 1s 79us/step
# [0.10320224250179708, 0.08999687640924486]

# %%
# inspect the predictions made by the model
predictions = dcf_model.predict(x={"user":X_test_u, "item":X_test_i})
print(np.min(predictions), np.max(predictions))
# Out:
# 0.5054111 0.99259055

# %% [markdown]
# This model has better overall performance and can produce different predictions. Nice!

# %% [markdown]
# ## Hybrid methods

# %% [markdown]
# ### Combine game metadata as extra features

# %%
# format game metadata
X_train_meta = train_full_idx.iloc[:,3:].values
X_test_meta = test_full_idx.iloc[:,3:].values

# %% [markdown]
# ### User-item interaction model using game features

# %% [markdown]
# #### Build the model

# %%
# define model variables
n_users = len(unique_users)
l2_param = 0.00000001
meta_features = X_train_meta.shape[1]
embedding_size_users = meta_features

# create user path
user_input = Input(shape=(1,), name="user")
user_embeddings = Embedding(n_users, 
                            embedding_size_users, 
                            embeddings_regularizer=l2(l2_param),
                            embeddings_initializer="glorot_normal",
                            name="user_embeddings")(user_input)
user_embeddings = Flatten(name="user_flattened")(user_embeddings)

# create item path
item_meta = Input(shape=(meta_features,), name="item_meta")

# combine the two paths
pred = dot([user_embeddings, item_meta], 1, name="pred_ratings")
#pred = BatchNormalization()(pred)
pred = Activation("sigmoid")(pred)

# compile the model
mcf_model = Model(inputs=[user_input, item_meta], outputs=pred)
mcf_model.compile("adam", loss="mse", metrics=["mse"])
mcf_model.summary()
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# user (InputLayer)               (None, 1)            0
# __________________________________________________________________________________________________
# user_embeddings (Embedding)     (None, 1, 62)        428172      user[0][0]
# __________________________________________________________________________________________________
# user_flattened (Flatten)        (None, 62)           0           user_embeddings[0][0]
# __________________________________________________________________________________________________
# item_meta (InputLayer)          (None, 62)           0
# __________________________________________________________________________________________________
# pred_ratings (Dot)              (None, 1)            0           user_flattened[0][0]
#                                                                  item_meta[0][0]
# __________________________________________________________________________________________________
# activation_17 (Activation)      (None, 1)            0           pred_ratings[0][0]
# ==================================================================================================
# Total params: 428,172
# Trainable params: 428,172
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %% [markdown]
# #### Train the model using CV

# %%
# define callbacks
reduce_lr = ReduceLROnPlateau("val_mean_squared_error", patience=5, verbose=1)
early_stop = EarlyStopping("val_mean_squared_error", min_delta=0.0001, patience=10, verbose=1)

# train model for a few epochs
mcf_model.fit(x={"user":X_train_u, "item_meta":X_train_meta}, 
              y=y_train, 
              batch_size=32, 
              epochs=50, 
              verbose=2, 
              validation_split=0.2,
              callbacks=[reduce_lr, early_stop]
             )
# Out:
# Train on 19975 samples, validate on 4994 samples
# Epoch 1/50
#  - 4s - loss: 0.2373 - mean_squared_error: 0.2372 - val_loss: 0.2217 - val_mean_squared_error: 0.2217
# Epoch 2/50
#  - 3s - loss: 0.1845 - mean_squared_error: 0.1845 - val_loss: 0.1966 - val_mean_squared_error: 0.1966
# Epoch 3/50
#  - 3s - loss: 0.1422 - mean_squared_error: 0.1421 - val_loss: 0.1792 - val_mean_squared_error: 0.1792
# Epoch 4/50
#  - 3s - loss: 0.1125 - mean_squared_error: 0.1125 - val_loss: 0.1671 - val_mean_squared_error: 0.1671
# Epoch 5/50
#  - 3s - loss: 0.0915 - mean_squared_error: 0.0915 - val_loss: 0.1587 - val_mean_squared_error: 0.1587
# Epoch 6/50
#  - 3s - loss: 0.0762 - mean_squared_error: 0.0762 - val_loss: 0.1529 - val_mean_squared_error: 0.1528
# Epoch 7/50
#  - 3s - loss: 0.0646 - mean_squared_error: 0.0646 - val_loss: 0.1486 - val_mean_squared_error: 0.1486
# Epoch 8/50
#  - 3s - loss: 0.0555 - mean_squared_error: 0.0555 - val_loss: 0.1457 - val_mean_squared_error: 0.1456
# Epoch 9/50
#  - 3s - loss: 0.0483 - mean_squared_error: 0.0483 - val_loss: 0.1436 - val_mean_squared_error: 0.1436
# Epoch 10/50
#  - 3s - loss: 0.0424 - mean_squared_error: 0.0423 - val_loss: 0.1422 - val_mean_squared_error: 0.1422
# Epoch 11/50
#  - 3s - loss: 0.0375 - mean_squared_error: 0.0374 - val_loss: 0.1413 - val_mean_squared_error: 0.1412
# Epoch 12/50
#  - 3s - loss: 0.0334 - mean_squared_error: 0.0333 - val_loss: 0.1408 - val_mean_squared_error: 0.1407
# Epoch 13/50
#  - 3s - loss: 0.0299 - mean_squared_error: 0.0298 - val_loss: 0.1406 - val_mean_squared_error: 0.1405
# Epoch 14/50
#  - 3s - loss: 0.0269 - mean_squared_error: 0.0268 - val_loss: 0.1406 - val_mean_squared_error: 0.1405
# Epoch 15/50
#  - 3s - loss: 0.0243 - mean_squared_error: 0.0242 - val_loss: 0.1408 - val_mean_squared_error: 0.1407
# Epoch 16/50
#  - 3s - loss: 0.0220 - mean_squared_error: 0.0219 - val_loss: 0.1411 - val_mean_squared_error: 0.1410
# Epoch 17/50
#  - 3s - loss: 0.0201 - mean_squared_error: 0.0199 - val_loss: 0.1416 - val_mean_squared_error: 0.1414
# Epoch 18/50
#  - 3s - loss: 0.0184 - mean_squared_error: 0.0182 - val_loss: 0.1420 - val_mean_squared_error: 0.1419
#
# Epoch 00018: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# Epoch 19/50
#  - 3s - loss: 0.0162 - mean_squared_error: 0.0161 - val_loss: 0.1421 - val_mean_squared_error: 0.1420
# Epoch 20/50
#  - 3s - loss: 0.0161 - mean_squared_error: 0.0160 - val_loss: 0.1422 - val_mean_squared_error: 0.1420
# Epoch 21/50
#  - 3s - loss: 0.0160 - mean_squared_error: 0.0158 - val_loss: 0.1422 - val_mean_squared_error: 0.1421
# Epoch 22/50
#  - 3s - loss: 0.0158 - mean_squared_error: 0.0157 - val_loss: 0.1423 - val_mean_squared_error: 0.1421
# Epoch 23/50
#  - 3s - loss: 0.0157 - mean_squared_error: 0.0155 - val_loss: 0.1424 - val_mean_squared_error: 0.1422
#
# Epoch 00023: ReduceLROnPlateau reducing learning rate to 1.0000000474974514e-05.
# Epoch 00023: early stopping

# %% [markdown]
# #### Evaluate performance on the test set

# %%
# evaluate on the test set
mcf_model.evaluate(x={"user":X_test_u, "item_meta":X_test_meta}, y=y_test)
# Out:
# 8323/8323 [==============================] - ETA:  - ETA:  - ETA:  - ETA:  - 0s 23us/step
# [0.12946291088119774, 0.12930250018172634]

# %%
# inspect the predictions made by the model
predictions = mcf_model.predict(x={"user":X_test_u, "item_meta":X_test_meta})
print(np.min(predictions), np.max(predictions))
# Out:
# 0.001375556 0.99954784

# %% [markdown]
# Performs worse than the pure matrix factorization model. Regularization parameter **L2** was super important for getting stable training!

# %% [markdown]
# ### Deep model with metadata features

# %%
from keras.optimizers import Adam

# %% [markdown]
# #### Build the model

# %%
# define model variables
n_users = len(unique_users)
n_items = len(unique_items)
embedding_size_users = 16
meta_features = X_train_meta.shape[1]

l2_param = 0.05
dropout_rate = 0.5

# create user path
user_input = Input(shape=(1,), name="user")
user_embeddings = Embedding(n_users, 
                            embedding_size_users, 
                            embeddings_regularizer=l2(l2_param),
                            embeddings_initializer="glorot_normal",
                            name="user_embeddings")(user_input)
user_embeddings = Flatten(name="user_flattened")(user_embeddings)

# create item path
item_meta = Input(shape=(meta_features,), name="item_meta")

# combine the two paths
user_item = concatenate([user_embeddings, item_meta], name="user_item")
user_item = Dropout(dropout_rate)(user_item)

# hidden layer 1
interaction = Dense(64, kernel_regularizer=l2(l2_param), bias_regularizer=l2(l2_param))(user_item)
interaction = BatchNormalization()(interaction)
interaction = Activation("relu")(interaction)
#interaction = Dropout(dropout_rate)(interaction)

# hidden layer 2
# interaction = Dense(32, kernel_regularizer=l2(l2_param), bias_regularizer=l2(l2_param))(interaction)
# interaction = BatchNormalization()(interaction)
# interaction = Activation("relu")(interaction)
# interaction = Dropout(dropout_rate)(interaction)

# output layer
pred = Dense(1, activation="sigmoid")(interaction)

# optimizer
opt = Adam(lr=0.00001)

# compile the model
dmcf_model = Model(inputs=[user_input, item_meta], outputs=pred)
dmcf_model.compile(opt, loss="mse", metrics=["mse"])
dmcf_model.summary()
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# user (InputLayer)               (None, 1)            0
# __________________________________________________________________________________________________
# user_embeddings (Embedding)     (None, 1, 16)        110496      user[0][0]
# __________________________________________________________________________________________________
# user_flattened (Flatten)        (None, 16)           0           user_embeddings[0][0]
# __________________________________________________________________________________________________
# item_meta (InputLayer)          (None, 62)           0
# __________________________________________________________________________________________________
# user_item (Concatenate)         (None, 78)           0           user_flattened[0][0]
#                                                                  item_meta[0][0]
# __________________________________________________________________________________________________
# dropout_52 (Dropout)            (None, 78)           0           user_item[0][0]
# __________________________________________________________________________________________________
# dense_90 (Dense)                (None, 64)           5056        dropout_52[0][0]
# __________________________________________________________________________________________________
# batch_normalization_55 (BatchNo (None, 64)           256         dense_90[0][0]
# __________________________________________________________________________________________________
# activation_67 (Activation)      (None, 64)           0           batch_normalization_55[0][0]
# __________________________________________________________________________________________________
# dense_91 (Dense)                (None, 1)            65          activation_67[0][0]
# ==================================================================================================
# Total params: 115,873
# Trainable params: 115,745
# Non-trainable params: 128
# __________________________________________________________________________________________________

# %% [markdown]
# #### Train the model using CV

# %%
# define callbacks
reduce_lr = ReduceLROnPlateau("val_mean_squared_error", patience=5, verbose=1)
early_stop = EarlyStopping("val_mean_squared_error", min_delta=0.0001, patience=10, verbose=1)

# train model for a few epochs
dmcf_model.fit(x={"user":X_train_u, "item_meta":X_train_meta}, 
              y=y_train, 
              batch_size=32, 
              epochs=50, 
              verbose=2, 
              validation_split=0.2,
              callbacks=[reduce_lr, early_stop]
             )
# Out:
# Train on 19975 samples, validate on 4994 samples
# Epoch 1/50
#  - 9s - loss: 4.9091 - mean_squared_error: 0.2711 - val_loss: 4.4206 - val_mean_squared_error: 0.2566
# Epoch 2/50
#  - 3s - loss: 4.0422 - mean_squared_error: 0.2389 - val_loss: 3.7154 - val_mean_squared_error: 0.2332
# Epoch 3/50
#  - 3s - loss: 3.4399 - mean_squared_error: 0.2125 - val_loss: 3.2118 - val_mean_squared_error: 0.2156
# Epoch 4/50
#  - 3s - loss: 2.9951 - mean_squared_error: 0.1889 - val_loss: 2.8329 - val_mean_squared_error: 0.2021
# Epoch 5/50
#  - 4s - loss: 2.6515 - mean_squared_error: 0.1699 - val_loss: 2.5273 - val_mean_squared_error: 0.1858
# Epoch 6/50
#  - 4s - loss: 2.3725 - mean_squared_error: 0.1539 - val_loss: 2.2748 - val_mean_squared_error: 0.1734
# Epoch 7/50
#  - 3s - loss: 2.1368 - mean_squared_error: 0.1415 - val_loss: 2.0561 - val_mean_squared_error: 0.1632
# Epoch 8/50
#  - 3s - loss: 1.9305 - mean_squared_error: 0.1323 - val_loss: 1.8615 - val_mean_squared_error: 0.1555
# Epoch 9/50
#  - 4s - loss: 1.7451 - mean_squared_error: 0.1256 - val_loss: 1.6834 - val_mean_squared_error: 0.1485
# Epoch 10/50
#  - 3s - loss: 1.5754 - mean_squared_error: 0.1204 - val_loss: 1.5189 - val_mean_squared_error: 0.1424
# Epoch 11/50
#  - 3s - loss: 1.4181 - mean_squared_error: 0.1156 - val_loss: 1.3676 - val_mean_squared_error: 0.1377
# Epoch 12/50
#  - 4s - loss: 1.2746 - mean_squared_error: 0.1133 - val_loss: 1.2273 - val_mean_squared_error: 0.1332
# Epoch 13/50
#  - 4s - loss: 1.1419 - mean_squared_error: 0.1110 - val_loss: 1.0994 - val_mean_squared_error: 0.1304
# Epoch 14/50
#  - 3s - loss: 1.0200 - mean_squared_error: 0.1091 - val_loss: 0.9807 - val_mean_squared_error: 0.1267
# Epoch 15/50
#  - 4s - loss: 0.9087 - mean_squared_error: 0.1078 - val_loss: 0.8746 - val_mean_squared_error: 0.1256
# Epoch 16/50
#  - 4s - loss: 0.8073 - mean_squared_error: 0.1067 - val_loss: 0.7767 - val_mean_squared_error: 0.1234
# Epoch 17/50
#  - 4s - loss: 0.7152 - mean_squared_error: 0.1057 - val_loss: 0.6891 - val_mean_squared_error: 0.1223
# Epoch 18/50
#  - 3s - loss: 0.6332 - mean_squared_error: 0.1060 - val_loss: 0.6101 - val_mean_squared_error: 0.1212
# Epoch 19/50
#  - 3s - loss: 0.5594 - mean_squared_error: 0.1059 - val_loss: 0.5395 - val_mean_squared_error: 0.1204
# Epoch 20/50
#  - 4s - loss: 0.4935 - mean_squared_error: 0.1059 - val_loss: 0.4768 - val_mean_squared_error: 0.1196
# Epoch 21/50
#  - 4s - loss: 0.4341 - mean_squared_error: 0.1048 - val_loss: 0.4217 - val_mean_squared_error: 0.1192
# Epoch 22/50
#  - 4s - loss: 0.3832 - mean_squared_error: 0.1051 - val_loss: 0.3737 - val_mean_squared_error: 0.1191
# Epoch 23/50
#  - 4s - loss: 0.3378 - mean_squared_error: 0.1044 - val_loss: 0.3312 - val_mean_squared_error: 0.1182
# Epoch 24/50
#  - 4s - loss: 0.2991 - mean_squared_error: 0.1045 - val_loss: 0.2951 - val_mean_squared_error: 0.1179
# Epoch 25/50
#  - 3s - loss: 0.2655 - mean_squared_error: 0.1040 - val_loss: 0.2646 - val_mean_squared_error: 0.1179
# Epoch 26/50
#  - 4s - loss: 0.2376 - mean_squared_error: 0.1041 - val_loss: 0.2388 - val_mean_squared_error: 0.1178
# Epoch 27/50
#  - 3s - loss: 0.2141 - mean_squared_error: 0.1041 - val_loss: 0.2178 - val_mean_squared_error: 0.1182
# Epoch 28/50
#  - 4s - loss: 0.1942 - mean_squared_error: 0.1037 - val_loss: 0.1998 - val_mean_squared_error: 0.1178
# Epoch 29/50
#  - 4s - loss: 0.1784 - mean_squared_error: 0.1037 - val_loss: 0.1858 - val_mean_squared_error: 0.1180
# Epoch 30/50
#  - 4s - loss: 0.1651 - mean_squared_error: 0.1033 - val_loss: 0.1738 - val_mean_squared_error: 0.1176
# Epoch 31/50
#  - 3s - loss: 0.1547 - mean_squared_error: 0.1032 - val_loss: 0.1652 - val_mean_squared_error: 0.1181
# Epoch 32/50
#  - 3s - loss: 0.1467 - mean_squared_error: 0.1033 - val_loss: 0.1580 - val_mean_squared_error: 0.1181
# Epoch 33/50
#  - 4s - loss: 0.1400 - mean_squared_error: 0.1031 - val_loss: 0.1523 - val_mean_squared_error: 0.1181
# Epoch 34/50
#  - 3s - loss: 0.1352 - mean_squared_error: 0.1033 - val_loss: 0.1482 - val_mean_squared_error: 0.1185
# Epoch 35/50
#  - 3s - loss: 0.1306 - mean_squared_error: 0.1027 - val_loss: 0.1448 - val_mean_squared_error: 0.1186
#
# Epoch 00035: ReduceLROnPlateau reducing learning rate to 9.999999747378752e-07.
# Epoch 36/50
#  - 4s - loss: 0.1286 - mean_squared_error: 0.1025 - val_loss: 0.1440 - val_mean_squared_error: 0.1180
# Epoch 37/50
#  - 3s - loss: 0.1286 - mean_squared_error: 0.1028 - val_loss: 0.1437 - val_mean_squared_error: 0.1181
# Epoch 38/50
#  - 4s - loss: 0.1280 - mean_squared_error: 0.1026 - val_loss: 0.1434 - val_mean_squared_error: 0.1181
# Epoch 39/50
#  - 4s - loss: 0.1278 - mean_squared_error: 0.1026 - val_loss: 0.1431 - val_mean_squared_error: 0.1181
# Epoch 40/50
#  - 3s - loss: 0.1274 - mean_squared_error: 0.1025 - val_loss: 0.1429 - val_mean_squared_error: 0.1182
#
# Epoch 00040: ReduceLROnPlateau reducing learning rate to 9.999999974752428e-08.
# Epoch 00040: early stopping

# %% [markdown]
# #### Evaluate performance on the test set

# %%
# evaluate on the test set
dmcf_model.evaluate(x={"user":X_test_u, "item_meta":X_test_meta}, y=y_test)
# Out:
# 8323/8323 [==============================] - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - 1s 69us/step
# [0.13524957502509888, 0.1104919669555956]

# %%
# inspect the predictions made by the model
predictions = dmcf_model.predict(x={"user":X_test_u, "item_meta":X_test_meta})
print(np.min(predictions), np.max(predictions))
# Out:
# 0.70679325 0.9272282

# %% [markdown]
# Model performs slightly better than the previous, but still not better than pure user-item factorization.

# %% [markdown]
# ### Deep user-item interaction model with additional item metadata

# %%
from keras.optimizers import Adam

# %% [markdown]
# #### Build the model

# %%
# define model variables
n_users = len(unique_users)
n_items = len(unique_items)
meta_features = X_train_meta.shape[1]
embedding_size_users = 16
embedding_size_items = 16
l2_param = 0.001
dropout_rate = 0.5

# create user path
user_input = Input(shape=(1,), name="user")
user_embeddings = Embedding(n_users, 
                            embedding_size_users, 
                            embeddings_regularizer=l2(l2_param),
                            embeddings_initializer="glorot_normal",
                            name="user_embeddings")(user_input)
user_flat = Flatten(name="user_flattened")(user_embeddings)

# create item path
item_input = Input(shape=(1,), name="item")
item_embeddings = Embedding(n_items, 
                            embedding_size_items,
                            embeddings_regularizer=l2(l2_param),
                            embeddings_initializer="glorot_normal",
                            name="item_embeddings")(item_input)
item_flat = Flatten(name="item_flattened")(item_embeddings)

# create item metadata path
item_meta = Input(shape=(meta_features,), name="item_meta")

# combine the two paths
user_item = concatenate([user_flat, item_flat, item_meta], name="user_item_meta")
#user_item = Dropout(dropout_rate)(user_item)

# hidden layer 1
interaction = Dense(32, kernel_regularizer=l2(l2_param), bias_regularizer=l2(l2_param))(user_item)
interaction = BatchNormalization()(interaction)
interaction = Activation("relu")(interaction)
interaction = Dropout(dropout_rate)(interaction)

# hidden layer 2
interaction = Dense(64, kernel_regularizer=l2(l2_param), bias_regularizer=l2(l2_param))(interaction)
interaction = BatchNormalization()(interaction)
interaction = Activation("relu")(interaction)
interaction = Dropout(dropout_rate)(interaction)

# hidden layer 3
interaction = Dense(32, kernel_regularizer=l2(l2_param), bias_regularizer=l2(l2_param))(interaction)
interaction = BatchNormalization()(interaction)
interaction = Activation("relu")(interaction)
#interaction = Dropout(dropout_rate)(interaction)

# output layer
pred = Dense(1, activation="sigmoid")(interaction)

# create optimizer
opt = Adam(lr=0.0001)

# compile the model
dmcf_model2 = Model(inputs=[user_input, item_input, item_meta], outputs=pred)
dmcf_model2.compile(opt, loss="mse", metrics=["mse"])
dmcf_model2.summary()
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# user (InputLayer)               (None, 1)            0
# __________________________________________________________________________________________________
# item (InputLayer)               (None, 1)            0
# __________________________________________________________________________________________________
# user_embeddings (Embedding)     (None, 1, 16)        110496      user[0][0]
# __________________________________________________________________________________________________
# item_embeddings (Embedding)     (None, 1, 16)        21536       item[0][0]
# __________________________________________________________________________________________________
# user_flattened (Flatten)        (None, 16)           0           user_embeddings[0][0]
# __________________________________________________________________________________________________
# item_flattened (Flatten)        (None, 16)           0           item_embeddings[0][0]
# __________________________________________________________________________________________________
# item_meta (InputLayer)          (None, 62)           0
# __________________________________________________________________________________________________
# user_item_meta (Concatenate)    (None, 94)           0           user_flattened[0][0]
#                                                                  item_flattened[0][0]
#                                                                  item_meta[0][0]
# __________________________________________________________________________________________________
# dense_63 (Dense)                (None, 32)           3040        user_item_meta[0][0]
# __________________________________________________________________________________________________
# batch_normalization_39 (BatchNo (None, 32)           128         dense_63[0][0]
# __________________________________________________________________________________________________
# activation_51 (Activation)      (None, 32)           0           batch_normalization_39[0][0]
# __________________________________________________________________________________________________
# dropout_37 (Dropout)            (None, 32)           0           activation_51[0][0]
# __________________________________________________________________________________________________
# dense_64 (Dense)                (None, 64)           2112        dropout_37[0][0]
# __________________________________________________________________________________________________
# batch_normalization_40 (BatchNo (None, 64)           256         dense_64[0][0]
# __________________________________________________________________________________________________
# activation_52 (Activation)      (None, 64)           0           batch_normalization_40[0][0]
# __________________________________________________________________________________________________
# dropout_38 (Dropout)            (None, 64)           0           activation_52[0][0]
# __________________________________________________________________________________________________
# dense_65 (Dense)                (None, 32)           2080        dropout_38[0][0]
# __________________________________________________________________________________________________
# batch_normalization_41 (BatchNo (None, 32)           128         dense_65[0][0]
# __________________________________________________________________________________________________
# activation_53 (Activation)      (None, 32)           0           batch_normalization_41[0][0]
# __________________________________________________________________________________________________
# dense_66 (Dense)                (None, 1)            33          activation_53[0][0]
# ==================================================================================================
# Total params: 139,809
# Trainable params: 139,553
# Non-trainable params: 256
# __________________________________________________________________________________________________

# %% [markdown]
# #### Train the model using CV

# %%
# define callbacks
reduce_lr = ReduceLROnPlateau("val_mean_squared_error", patience=5, verbose=1)
early_stop = EarlyStopping("val_mean_squared_error", min_delta=0.0001, patience=20, verbose=1)

# train model for a few epochs
dmcf_model2.fit(x={"user":X_train_u, "item":X_train_i, "item_meta":X_train_meta}, 
              y=y_train, 
              batch_size=32, 
              epochs=200, 
              verbose=2, 
              validation_split=0.2,
              callbacks=[reduce_lr, early_stop]
             )
# Out:
# Train on 19975 samples, validate on 4994 samples
# Epoch 1/200
#  - 11s - loss: 0.3001 - mean_squared_error: 0.1506 - val_loss: 0.2738 - val_mean_squared_error: 0.1461
# Epoch 2/200
#  - 4s - loss: 0.2295 - mean_squared_error: 0.1135 - val_loss: 0.2313 - val_mean_squared_error: 0.1253
# Epoch 3/200
#  - 4s - loss: 0.2057 - mean_squared_error: 0.1077 - val_loss: 0.2084 - val_mean_squared_error: 0.1176
# Epoch 4/200
#  - 5s - loss: 0.1906 - mean_squared_error: 0.1059 - val_loss: 0.1943 - val_mean_squared_error: 0.1154
# Epoch 5/200
#  - 5s - loss: 0.1793 - mean_squared_error: 0.1054 - val_loss: 0.1830 - val_mean_squared_error: 0.1139
# Epoch 6/200
#  - 5s - loss: 0.1697 - mean_squared_error: 0.1049 - val_loss: 0.1742 - val_mean_squared_error: 0.1134
# Epoch 7/200
#  - 4s - loss: 0.1617 - mean_squared_error: 0.1045 - val_loss: 0.1667 - val_mean_squared_error: 0.1128
# Epoch 8/200
#  - 4s - loss: 0.1548 - mean_squared_error: 0.1039 - val_loss: 0.1614 - val_mean_squared_error: 0.1134
# Epoch 9/200
#  - 4s - loss: 0.1493 - mean_squared_error: 0.1039 - val_loss: 0.1560 - val_mean_squared_error: 0.1129
# Epoch 10/200
#  - 4s - loss: 0.1444 - mean_squared_error: 0.1035 - val_loss: 0.1514 - val_mean_squared_error: 0.1125
# Epoch 11/200
#  - 4s - loss: 0.1402 - mean_squared_error: 0.1031 - val_loss: 0.1475 - val_mean_squared_error: 0.1122
# Epoch 12/200
#  - 4s - loss: 0.1369 - mean_squared_error: 0.1032 - val_loss: 0.1440 - val_mean_squared_error: 0.1118
# Epoch 13/200
#  - 4s - loss: 0.1336 - mean_squared_error: 0.1028 - val_loss: 0.1416 - val_mean_squared_error: 0.1121
# Epoch 14/200
#  - 4s - loss: 0.1309 - mean_squared_error: 0.1026 - val_loss: 0.1385 - val_mean_squared_error: 0.1114
# Epoch 15/200
#  - 4s - loss: 0.1283 - mean_squared_error: 0.1023 - val_loss: 0.1360 - val_mean_squared_error: 0.1110
# Epoch 16/200
#  - 4s - loss: 0.1265 - mean_squared_error: 0.1025 - val_loss: 0.1342 - val_mean_squared_error: 0.1112
# Epoch 17/200
#  - 4s - loss: 0.1243 - mean_squared_error: 0.1021 - val_loss: 0.1318 - val_mean_squared_error: 0.1104
# Epoch 18/200
#  - 4s - loss: 0.1227 - mean_squared_error: 0.1021 - val_loss: 0.1308 - val_mean_squared_error: 0.1109
# Epoch 19/200
#  - 4s - loss: 0.1208 - mean_squared_error: 0.1016 - val_loss: 0.1289 - val_mean_squared_error: 0.1104
# Epoch 20/200
#  - 4s - loss: 0.1193 - mean_squared_error: 0.1015 - val_loss: 0.1268 - val_mean_squared_error: 0.1095
# Epoch 21/200
#  - 4s - loss: 0.1173 - mean_squared_error: 0.1006 - val_loss: 0.1261 - val_mean_squared_error: 0.1099
# Epoch 22/200
#  - 4s - loss: 0.1164 - mean_squared_error: 0.1007 - val_loss: 0.1243 - val_mean_squared_error: 0.1092
# Epoch 23/200
#  - 4s - loss: 0.1155 - mean_squared_error: 0.1008 - val_loss: 0.1231 - val_mean_squared_error: 0.1089
# Epoch 24/200
#  - 4s - loss: 0.1146 - mean_squared_error: 0.1008 - val_loss: 0.1221 - val_mean_squared_error: 0.1087
# Epoch 25/200
#  - 4s - loss: 0.1135 - mean_squared_error: 0.1005 - val_loss: 0.1219 - val_mean_squared_error: 0.1093
# Epoch 26/200
#  - 4s - loss: 0.1129 - mean_squared_error: 0.1007 - val_loss: 0.1222 - val_mean_squared_error: 0.1103
# Epoch 27/200
#  - 4s - loss: 0.1121 - mean_squared_error: 0.1005 - val_loss: 0.1204 - val_mean_squared_error: 0.1092
# Epoch 28/200
#  - 4s - loss: 0.1114 - mean_squared_error: 0.1005 - val_loss: 0.1191 - val_mean_squared_error: 0.1085
# Epoch 29/200
#  - 4s - loss: 0.1103 - mean_squared_error: 0.0999 - val_loss: 0.1192 - val_mean_squared_error: 0.1092
# Epoch 30/200
#  - 4s - loss: 0.1096 - mean_squared_error: 0.0998 - val_loss: 0.1177 - val_mean_squared_error: 0.1082
# Epoch 31/200
#  - 4s - loss: 0.1091 - mean_squared_error: 0.0998 - val_loss: 0.1172 - val_mean_squared_error: 0.1081
# Epoch 32/200
#  - 4s - loss: 0.1088 - mean_squared_error: 0.0999 - val_loss: 0.1169 - val_mean_squared_error: 0.1083
# Epoch 33/200
#  - 5s - loss: 0.1078 - mean_squared_error: 0.0994 - val_loss: 0.1158 - val_mean_squared_error: 0.1076
# Epoch 34/200
#  - 5s - loss: 0.1073 - mean_squared_error: 0.0993 - val_loss: 0.1155 - val_mean_squared_error: 0.1076
# Epoch 35/200
#  - 5s - loss: 0.1069 - mean_squared_error: 0.0992 - val_loss: 0.1149 - val_mean_squared_error: 0.1074
# Epoch 36/200
#  - 4s - loss: 0.1063 - mean_squared_error: 0.0989 - val_loss: 0.1148 - val_mean_squared_error: 0.1075
# Epoch 37/200
#  - 4s - loss: 0.1064 - mean_squared_error: 0.0993 - val_loss: 0.1140 - val_mean_squared_error: 0.1070
# Epoch 38/200
#  - 4s - loss: 0.1058 - mean_squared_error: 0.0990 - val_loss: 0.1135 - val_mean_squared_error: 0.1068
# Epoch 39/200
#  - 4s - loss: 0.1053 - mean_squared_error: 0.0986 - val_loss: 0.1123 - val_mean_squared_error: 0.1057
# Epoch 40/200
#  - 4s - loss: 0.1043 - mean_squared_error: 0.0977 - val_loss: 0.1125 - val_mean_squared_error: 0.1060
# Epoch 41/200
#  - 4s - loss: 0.1042 - mean_squared_error: 0.0977 - val_loss: 0.1116 - val_mean_squared_error: 0.1052
# Epoch 42/200
#  - 4s - loss: 0.1040 - mean_squared_error: 0.0977 - val_loss: 0.1118 - val_mean_squared_error: 0.1055
# Epoch 43/200
#  - 4s - loss: 0.1032 - mean_squared_error: 0.0970 - val_loss: 0.1110 - val_mean_squared_error: 0.1048
# Epoch 44/200
#  - 4s - loss: 0.1032 - mean_squared_error: 0.0971 - val_loss: 0.1104 - val_mean_squared_error: 0.1043
# Epoch 45/200
#  - 4s - loss: 0.1029 - mean_squared_error: 0.0969 - val_loss: 0.1109 - val_mean_squared_error: 0.1050
# Epoch 46/200
#  - 4s - loss: 0.1028 - mean_squared_error: 0.0969 - val_loss: 0.1101 - val_mean_squared_error: 0.1043
# Epoch 47/200
#  - 4s - loss: 0.1026 - mean_squared_error: 0.0968 - val_loss: 0.1100 - val_mean_squared_error: 0.1043
# Epoch 48/200
#  - 4s - loss: 0.1019 - mean_squared_error: 0.0962 - val_loss: 0.1092 - val_mean_squared_error: 0.1036
# Epoch 49/200
#  - 4s - loss: 0.1015 - mean_squared_error: 0.0960 - val_loss: 0.1098 - val_mean_squared_error: 0.1043
# Epoch 50/200
#  - 4s - loss: 0.1017 - mean_squared_error: 0.0962 - val_loss: 0.1096 - val_mean_squared_error: 0.1041
# Epoch 51/200
#  - 4s - loss: 0.1011 - mean_squared_error: 0.0957 - val_loss: 0.1086 - val_mean_squared_error: 0.1033
# Epoch 52/200
#  - 4s - loss: 0.1005 - mean_squared_error: 0.0952 - val_loss: 0.1095 - val_mean_squared_error: 0.1042
# Epoch 53/200
#  - 4s - loss: 0.1005 - mean_squared_error: 0.0952 - val_loss: 0.1099 - val_mean_squared_error: 0.1048
# Epoch 54/200
#  - 4s - loss: 0.1006 - mean_squared_error: 0.0955 - val_loss: 0.1078 - val_mean_squared_error: 0.1027
# Epoch 55/200
#  - 4s - loss: 0.1001 - mean_squared_error: 0.0951 - val_loss: 0.1097 - val_mean_squared_error: 0.1048
# Epoch 56/200
#  - 4s - loss: 0.0999 - mean_squared_error: 0.0950 - val_loss: 0.1092 - val_mean_squared_error: 0.1043
# Epoch 57/200
#  - 4s - loss: 0.1000 - mean_squared_error: 0.0952 - val_loss: 0.1087 - val_mean_squared_error: 0.1039
# Epoch 58/200
#  - 4s - loss: 0.0998 - mean_squared_error: 0.0950 - val_loss: 0.1071 - val_mean_squared_error: 0.1023
# Epoch 59/200
#  - 4s - loss: 0.0994 - mean_squared_error: 0.0947 - val_loss: 0.1077 - val_mean_squared_error: 0.1031
# Epoch 60/200
#  - 4s - loss: 0.0988 - mean_squared_error: 0.0942 - val_loss: 0.1086 - val_mean_squared_error: 0.1039
# Epoch 61/200
#  - 4s - loss: 0.0993 - mean_squared_error: 0.0947 - val_loss: 0.1064 - val_mean_squared_error: 0.1019
# Epoch 62/200
#  - 4s - loss: 0.0993 - mean_squared_error: 0.0947 - val_loss: 0.1084 - val_mean_squared_error: 0.1039
# Epoch 63/200
#  - 4s - loss: 0.0993 - mean_squared_error: 0.0948 - val_loss: 0.1077 - val_mean_squared_error: 0.1032
# Epoch 64/200
#  - 4s - loss: 0.0987 - mean_squared_error: 0.0943 - val_loss: 0.1066 - val_mean_squared_error: 0.1022
# Epoch 65/200
#  - 4s - loss: 0.0989 - mean_squared_error: 0.0946 - val_loss: 0.1062 - val_mean_squared_error: 0.1019
# Epoch 66/200
#  - 4s - loss: 0.0984 - mean_squared_error: 0.0941 - val_loss: 0.1079 - val_mean_squared_error: 0.1036
#
# Epoch 00066: ReduceLROnPlateau reducing learning rate to 9.999999747378752e-06.
# Epoch 67/200
#  - 4s - loss: 0.0981 - mean_squared_error: 0.0938 - val_loss: 0.1072 - val_mean_squared_error: 0.1029
# Epoch 68/200
#  - 4s - loss: 0.0978 - mean_squared_error: 0.0936 - val_loss: 0.1074 - val_mean_squared_error: 0.1032
# Epoch 69/200
#  - 4s - loss: 0.0982 - mean_squared_error: 0.0940 - val_loss: 0.1077 - val_mean_squared_error: 0.1035
# Epoch 70/200
#  - 4s - loss: 0.0972 - mean_squared_error: 0.0930 - val_loss: 0.1070 - val_mean_squared_error: 0.1028
# Epoch 71/200
#  - 4s - loss: 0.0982 - mean_squared_error: 0.0940 - val_loss: 0.1073 - val_mean_squared_error: 0.1031
# Epoch 00071: ReduceLROnPlateau reducing learning rate to 9.999999747378752e-07.
# Epoch 72/200
#  - 4s - loss: 0.0976 - mean_squared_error: 0.0934 - val_loss: 0.1072 - val_mean_squared_error: 0.1031
# Epoch 73/200
#  - 4s - loss: 0.0978 - mean_squared_error: 0.0936 - val_loss: 0.1076 - val_mean_squared_error: 0.1034
# Epoch 74/200
#  - 4s - loss: 0.0980 - mean_squared_error: 0.0938 - val_loss: 0.1073 - val_mean_squared_error: 0.1031
# Epoch 75/200
#  - 4s - loss: 0.0978 - mean_squared_error: 0.0936 - val_loss: 0.1074 - val_mean_squared_error: 0.1032
# Epoch 76/200
#  - 4s - loss: 0.0976 - mean_squared_error: 0.0934 - val_loss: 0.1073 - val_mean_squared_error: 0.1031
#
# Epoch 00076: ReduceLROnPlateau reducing learning rate to 9.999999974752428e-08.
# Epoch 77/200
#  - 4s - loss: 0.0978 - mean_squared_error: 0.0936 - val_loss: 0.1073 - val_mean_squared_error: 0.1032
# Epoch 78/200
#  - 4s - loss: 0.0977 - mean_squared_error: 0.0936 - val_loss: 0.1074 - val_mean_squared_error: 0.1032
# Epoch 79/200
#  - 4s - loss: 0.0972 - mean_squared_error: 0.0930 - val_loss: 0.1076 - val_mean_squared_error: 0.1034
# Epoch 80/200
#  - 4s - loss: 0.0979 - mean_squared_error: 0.0937 - val_loss: 0.1074 - val_mean_squared_error: 0.1032
# Epoch 81/200
#  - 4s - loss: 0.0978 - mean_squared_error: 0.0936 - val_loss: 0.1073 - val_mean_squared_error: 0.1031
#
# Epoch 00081: ReduceLROnPlateau reducing learning rate to 1.0000000116860975e-08.
# Epoch 00081: early stopping

# %% [markdown]
# #### Evaluate performance on the test set

# %%
# evaluate on the test set
dmcf_model2.evaluate(x={"user":X_test_u, "item":X_test_i, "item_meta":X_test_meta}, y=y_test)
# Out:
# 8323/8323 [==============================] - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - 0s 55us/step
# [0.09948294307080066, 0.09530307795544929]

# %%
# inspect the predictions made by the model
predictions = dmcf_model2.predict(x={"user":X_test_u, "item":X_test_i, "item_meta":X_test_meta})
print(np.min(predictions), np.max(predictions))
# Out:
# 0.48924494 0.96381783

# %% [markdown]
# Best among the hybrid models but still performs worse than the deep CF model. Learning rate was the most important parameter to get stable learning (needed to reduce it from the default value)

# %% [markdown]
# ## Conclusions
#
# The best model is the **deep user-item interaction model** (with only user/item embeddings) that does not use the game metadata information. It achieves a **MSE = 0.090** on the test set.
#
# The two most important parameters to tweak in order to get stable training and not overfit were the learning rate and the regularization strength.
