# %% [markdown]
# # Game RecSys Model Building
# In this notebook, I build several models of user-game ratings and test their performance against the baseline models developed using the `surprise` package

# %% [markdown]
# ## Load and format data

# %%
import numpy as np
import pandas as pd
import gzip
from functools import reduce
import matplotlib.pyplot as plt
# %matplotlib inline

import seaborn as sns
sns.set()

# %%
GAME_METADATA_PATH = "data/steam_games.json.gz"

# %% [markdown]
# ### Load user-game ratings data
# #### Training data

# %%
X_train = pd.read_csv("train_test_split/X_train_3k.csv")
X_train = X_train.set_index("Unnamed: 0")
y_train = pd.read_csv("train_test_split/y_train_3k.csv")
y_train = y_train.set_index("Unnamed: 0")
# join and reset index
train_df = pd.merge(X_train, y_train, left_index=True, right_index=True, validate="1:1")
train_df = train_df.reset_index(drop=True)[["user_id", "item_id", "recommend"]].copy()

# %%
train_df.head()
# Out:
#              user_id  item_id  recommend
# 0          Drewmatic     8930          1
# 1  76561198080148447   377160          1
# 2   AleksoSmeksoHere   342380          1
# 3            gaboqse   108800          0
# 4            piedude   215470          1

# %% [markdown]
# #### Test data

# %%
X_test = pd.read_csv("train_test_split/X_test_3k.csv")
X_test = X_test.set_index("Unnamed: 0")
y_test = pd.read_csv("train_test_split/y_test_3k.csv")
y_test = y_test.set_index("Unnamed: 0")
# join and reset index
test_df = pd.merge(X_test, y_test, left_index=True, right_index=True, validate="1:1")
test_df = test_df.reset_index(drop=True)[["user_id", "item_id", "recommend"]].copy()

# %%
test_df.head()
# Out:
#                       user_id  item_id  recommend
# 0                 sickbubblez   386360          1
# 1  GetALifeStopLookingAtMyUrl     4000          1
# 2                 kineticvine     1250          1
# 3                   LeoNoHomo   200210          1
# 4                itsdandytime     4000          1

# %% [markdown]
# ### Load and format game metadata

# %%
def parse_gzipped_all(path):
    """reads the gzipped input data file in path
    returns - a list of dictionaries"""
    with gzip.open(path, "r") as g:
        data = [eval(l) for l in g.readlines()]
    return data

def parse_data_all(path):
    """reads the input data file in path
    returns - a list of dictionaries"""
    with open(path, "r", errors="ignore") as f:
        data = [eval(l) for l in f.readlines()]
    return data

# %% [markdown]
# #### Load *Steam* game metadata

# %%
game_meta = parse_gzipped_all(GAME_METADATA_PATH)
game_meta_df = pd.DataFrame.from_records(game_meta).dropna(subset=["id"])
game_meta_df["id"] = game_meta_df["id"].astype(int)
game_meta_df = game_meta_df.set_index("id")
game_meta_df.head()
# Out:
#                        app_name         developer  discount_price  \
# id
# 761140      Lost Summoner Kitty         Kotoshiro            4.49
# 643980                Ironbound  Secret Level SRL             NaN
# 670290  Real Pool 3D - Poolians      Poolians.com             NaN
# 767400                  弹炸人2222              彼岸领域            0.83
# 773570            Log Challenge               NaN            1.79
#
#         early_access                                             genres  \
# id
# 761140         False      [Action, Casual, Indie, Simulation, Strategy]
# 643980         False               [Free to Play, Indie, RPG, Strategy]
# 670290         False  [Casual, Free to Play, Indie, Simulation, Sports]
# 767400         False                        [Action, Adventure, Casual]
# 773570         False                                                NaN
#
#        metascore         price         publisher release_date  \
# id
# 761140       NaN          4.99         Kotoshiro   2018-01-04
# 643980       NaN  Free To Play  Making Fun, Inc.   2018-01-04
# 670290       NaN  Free to Play      Poolians.com   2017-07-24
# 767400       NaN          0.99              彼岸领域   2017-12-07
# 773570       NaN          2.99               NaN          NaN
#
#                                               reviews_url        sentiment  \
# id
# 761140  http://steamcommunity.com/app/761140/reviews/?...              NaN
# 643980  http://steamcommunity.com/app/643980/reviews/?...  Mostly Positive
# 670290  http://steamcommunity.com/app/670290/reviews/?...  Mostly Positive
# 767400  http://steamcommunity.com/app/767400/reviews/?...              NaN
# 773570  http://steamcommunity.com/app/773570/reviews/?...              NaN
#
#                                                     specs  \
# id
# 761140                                    [Single-player]
# 643980  [Single-player, Multi-player, Online Multi-Pla...
# 670290  [Single-player, Multi-player, Online Multi-Pla...
# 767400                                    [Single-player]
# 773570  [Single-player, Full controller support, HTC V...
#
#                                                      tags  \
# id
# 761140      [Strategy, Action, Indie, Casual, Simulation]
# 643980  [Free to Play, Strategy, Indie, RPG, Card Game...
# 670290  [Free to Play, Simulation, Sports, Casual, Ind...
# 767400                        [Action, Adventure, Casual]
# 773570                    [Action, Indie, Casual, Sports]
#
#                           title  \
# id
# 761140      Lost Summoner Kitty
# 643980                Ironbound
# 670290  Real Pool 3D - Poolians
# 767400                  弹炸人2222
# 773570                      NaN
#
#                                                       url
# id
# 761140  http://store.steampowered.com/app/761140/Lost_...
# 643980  http://store.steampowered.com/app/643980/Ironb...
# 670290  http://store.steampowered.com/app/670290/Real_...
# 767400     http://store.steampowered.com/app/767400/2222/
# 773570  http://store.steampowered.com/app/773570/Log_C...

# %% [markdown]
# #### Keep only game ID:s that are in the training set

# %%
game_ids = pd.Series(train_df["item_id"].unique(), name="item_id").to_frame().set_index("item_id")
game_meta_train = game_ids.merge(game_meta_df, how="inner", left_index=True, right_index=True)
game_meta_train.head()
# Out:
#                      app_name         developer  discount_price  early_access  \
# 10             Counter-Strike             Valve             NaN         False
# 20      Team Fortress Classic             Valve             NaN         False
# 30              Day of Defeat             Valve             NaN         False
# 50  Half-Life: Opposing Force  Gearbox Software             NaN         False
# 60                   Ricochet             Valve             NaN         False
#
#       genres metascore price publisher release_date  \
# 10  [Action]        88  9.99     Valve   2000-11-01
# 20  [Action]       NaN  4.99     Valve   1999-04-01
# 30  [Action]        79  4.99     Valve   2003-05-01
# 50  [Action]       NaN  4.99     Valve   1999-11-01
# 60  [Action]       NaN  4.99     Valve   2000-11-01
#
#                                           reviews_url  \
# 10  http://steamcommunity.com/app/10/reviews/?brow...
# 20  http://steamcommunity.com/app/20/reviews/?brow...
# 30  http://steamcommunity.com/app/30/reviews/?brow...
# 50  http://steamcommunity.com/app/50/reviews/?brow...
# 60  http://steamcommunity.com/app/60/reviews/?brow...
#
#                   sentiment  \
# 10  Overwhelmingly Positive
# 20            Very Positive
# 30            Very Positive
# 50            Very Positive
# 60          Mostly Positive
#
#                                                 specs  \
# 10           [Multi-player, Valve Anti-Cheat enabled]
# 20           [Multi-player, Valve Anti-Cheat enabled]
# 30           [Multi-player, Valve Anti-Cheat enabled]
# 50  [Single-player, Multi-player, Valve Anti-Cheat...
# 60           [Multi-player, Valve Anti-Cheat enabled]
#
#                                                  tags  \
# 10  [Action, FPS, Multiplayer, Shooter, Classic, T...
# 20  [Action, FPS, Multiplayer, Classic, Shooter, C...
# 30  [FPS, World War II, Multiplayer, Action, Shoot...
# 50  [FPS, Action, Sci-fi, Singleplayer, Classic, S...
# 60  [Action, FPS, Multiplayer, First-Person, Cyber...
#
#                         title  \
# 10             Counter-Strike
# 20      Team Fortress Classic
# 30              Day of Defeat
# 50  Half-Life: Opposing Force
# 60                   Ricochet
#
#                                                   url
# 10  http://store.steampowered.com/app/10/CounterSt...
# 20  http://store.steampowered.com/app/20/Team_Fort...
# 30  http://store.steampowered.com/app/30/Day_of_De...
# 50  http://store.steampowered.com/app/50/HalfLife_...
# 60     http://store.steampowered.com/app/60/Ricochet/

# %% [markdown]
# #### Clean and re-format the dataset

# %%
# drop columns we will not use
game_meta_train.drop(columns=["title", "url", "discount_price", "release_date", "reviews_url"], inplace=True)
game_meta_train.head()

# %%
# convert data types
num_cols = ["metascore", "price"]
game_meta_train[num_cols] = game_meta_train[num_cols].apply(pd.to_numeric, errors='coerce')
game_meta_train["early_access"] = game_meta_train["early_access"].astype(int)

# %%
# map sentiment to ordinal values
map_sentiment = {
    "Overwhelmingly Negative":-3,
    "Very Negative":-2,
    "Mostly Negative":-1,
    "Mixed": 0,
    "Mostly Positive": 1,
    "Very Positive": 2,
    "Overwhelmingly Positive":3
}
game_meta_train["sentiment"].replace(map_sentiment, inplace=True)

# %%
# drop columns that result in a too large feature set
game_meta_base = game_meta_train.drop(columns=["app_name", "developer", "publisher", "tags"])
game_meta_base.head()
# Out:
#     early_access    genres  metascore  price  sentiment  \
# 10             0  [Action]       88.0   9.99          3
# 20             0  [Action]        NaN   4.99          2
# 30             0  [Action]       79.0   4.99          2
# 50             0  [Action]        NaN   4.99          2
# 60             0  [Action]        NaN   4.99          1
#
#                                                 specs
# 10           [Multi-player, Valve Anti-Cheat enabled]
# 20           [Multi-player, Valve Anti-Cheat enabled]
# 30           [Multi-player, Valve Anti-Cheat enabled]
# 50  [Single-player, Multi-player, Valve Anti-Cheat...
# 60           [Multi-player, Valve Anti-Cheat enabled]

# %% [markdown]
# #### Encode multi-label categorical features (Multi-label binarization)

# %%
from sklearn.preprocessing import MultiLabelBinarizer

# %%
def encode_multi(df, col):
    """encodes a single column"""
    mlb = MultiLabelBinarizer()
    # first drop nans
    df = df[col].dropna()
    # encode feature list
    encoded = mlb.fit_transform(df)
    encoded_df = pd.DataFrame(data=encoded, columns=mlb.classes_, index=df.index)
    return encoded_df

def encode_all(df, cols):
    """encodes all columns and combines
    the results into a single df"""
    df = df.copy(deep=True)
    for c in cols:
        encoded_col = encode_multi(df, c)
        df = pd.merge(df, encoded_col, how="left", left_index=True, right_index=True).drop(columns=c)
    return df

# %%
game_meta_encoded = encode_all(game_meta_base, ["genres", "specs"])

# %%
game_meta_encoded.head()
# Out:
#     early_access  metascore  price  sentiment  Action  Adventure  \
# 10             0       88.0   9.99          3     1.0        0.0
# 20             0        NaN   4.99          2     1.0        0.0
# 30             0       79.0   4.99          2     1.0        0.0
# 50             0        NaN   4.99          2     1.0        0.0
# 60             0        NaN   4.99          1     1.0        0.0
#
#     Animation &amp; Modeling  Audio Production  Casual  \
# 10                       0.0               0.0     0.0
# 20                       0.0               0.0     0.0
# 30                       0.0               0.0     0.0
# 50                       0.0               0.0     0.0
# 60                       0.0               0.0     0.0
#
#     Design &amp; Illustration  ...  Stats  Steam Achievements  Steam Cloud  \
# 10                        0.0  ...    0.0                 0.0          0.0
# 20                        0.0  ...    0.0                 0.0          0.0
# 30                        0.0  ...    0.0                 0.0          0.0
# 50                        0.0  ...    0.0                 0.0          0.0
# 60                        0.0  ...    0.0                 0.0          0.0
#
#     Steam Leaderboards  Steam Trading Cards  Steam Turn Notifications  \
# 10                 0.0                  0.0                       0.0
# 20                 0.0                  0.0                       0.0
# 30                 0.0                  0.0                       0.0
# 50                 0.0                  0.0                       0.0
# 60                 0.0                  0.0                       0.0
#
#     Steam Workshop  SteamVR Collectibles  Tracked Motion Controllers  \
# 10             0.0                   0.0                         0.0
# 20             0.0                   0.0                         0.0
# 30             0.0                   0.0                         0.0
# 50             0.0                   0.0                         0.0
# 60             0.0                   0.0                         0.0
#
#     Valve Anti-Cheat enabled
# 10                       1.0
# 20                       1.0
# 30                       1.0
# 50                       1.0
# 60                       1.0
#
# [5 rows x 62 columns]

# %% [markdown]
# #### Assemble full metadata set

# %%
full_meta = pd.merge(game_ids, game_meta_encoded, how="left", left_index=True, right_index=True)
full_meta.shape
# Out:
# (1346, 62)

# %% [markdown]
# #### Fill NaN:s and normalize values in `metascore`, `price`, and `sentiment` columns

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
# fill NaN:s with column mean values
full_meta.fillna(full_meta.mean(), inplace=True)

# normalize values in the 2 columns
scaler = MinMaxScaler()
scaled = scaler.fit_transform(full_meta[["metascore", "price", "sentiment"]])
full_meta[["metascore", "price", "sentiment"]] = scaled

# %%
full_meta.head()
# Out:
#          early_access  metascore     price  sentiment    Action  Adventure  \
# item_id
# 8930         0.000000   0.916667  0.038251   1.000000  0.000000   0.000000
# 377160       0.000000   0.833333  0.038251   0.500000  0.000000   0.000000
# 342380       0.050633   0.735917  0.021977   0.764838  0.594991   0.303972
# 108800       0.000000   0.735917  0.038251   0.833333  1.000000   0.000000
# 215470       0.000000   0.597222  0.009725   0.666667  1.000000   0.000000
#
#          Animation &amp; Modeling  Audio Production    Casual  \
# item_id
# 8930                     0.000000          0.000000  0.000000
# 377160                   0.000000          0.000000  0.000000
# 342380                   0.004318          0.000864  0.124352
# 108800                   0.000000          0.000000  0.000000
# 215470                   0.000000          0.000000  0.000000
#
#          Design &amp; Illustration  ...     Stats  Steam Achievements  \
# item_id                             ...
# 8930                      0.000000  ...  0.000000            1.000000
# 377160                    0.000000  ...  0.000000            1.000000
# 342380                    0.001727  ...  0.119898            0.637755
# 108800                    0.000000  ...  0.000000            0.000000
# 215470                    0.000000  ...  0.000000            1.000000
#
#          Steam Cloud  Steam Leaderboards  Steam Trading Cards  \
# item_id
# 8930        1.000000            0.000000              1.00000
# 377160      1.000000            0.000000              0.00000
# 342380      0.417517            0.213435              0.52551
# 108800      0.000000            0.000000              0.00000
# 215470      0.000000            0.000000              1.00000
#
#          Steam Turn Notifications  Steam Workshop  SteamVR Collectibles  \
# item_id
# 8930                     0.000000        0.000000               0.00000
# 377160                   0.000000        0.000000               0.00000
# 342380                   0.002551        0.142857               0.00085
# 108800                   0.000000        0.000000               0.00000
# 215470                   0.000000        0.000000               0.00000
#
#          Tracked Motion Controllers  Valve Anti-Cheat enabled
# item_id
# 8930                       0.000000                  0.000000
# 377160                     0.000000                  0.000000
# 342380                     0.005952                  0.064626
# 108800                     0.000000                  0.000000
# 215470                     0.000000                  1.000000
#
# [5 rows x 62 columns]

# %%
# persist processed game data
full_meta.to_csv("train_test_split/processed_metadata.csv")

# %% [markdown]
# ## Content-based filtering (CBF)

# %% [markdown]
# ### Compute game-game similarity matrix

# %% [markdown]
# ### CBF algorithm

# %% [markdown]
# ### CBF evaluation

# %% [markdown]
# ## Collaborative filtering (CF) using deep learning

# %% [markdown]
# ## Hybrid methods
